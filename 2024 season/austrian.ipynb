# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fastf1 as f1

# %%
f1.Cache.enable_cache('../cache')

# %% [markdown]
# # Austrian Grand Prix 2024

# %% [markdown]
# **Qualifying**

# %%
quali = f1.get_session(2024,"Austria","Qualifying")
quali.load()
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Qualifying [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 12: Position data is incomplete!
# _api        WARNING 	Driver  2: Position data is incomplete!
# _api        WARNING 	Driver  3: Position data is incomplete!
# _api        WARNING 	Driver  4: Position data is incomplete!
# _api        WARNING 	Driver 10: Position data is incomplete!
# _api        WARNING 	Driver 11: Position data is incomplete!
# _api        WARNING 	Driver 14: Position data is incomplete!
# _api        WARNING 	Driver 16: Position data is incomplete!
# _api        WARNING 	Driver 18: Position data is incomplete!
# _api        WARNING 	Driver 20: Position data is incomplete!
# _api        WARNING 	Driver 22: Position data is incomplete!
# _api        WARNING 	Driver 23: Position data is incomplete!
# _api        WARNING 	Driver 27: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 81: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '55', '44', '16', '81', '11', '27', '31', '3', '20', '10', '22', '14', '23', '18', '77', '2', '24']

# %%
quali.session_info
# Out:
# {'Meeting': {'Key': 1239,
#   'Name': 'Austrian Grand Prix',
#   'OfficialName': 'FORMULA 1 QATAR AIRWAYS AUSTRIAN GRAND PRIX 2024',
#   'Location': 'Spielberg',
#   'Country': {'Key': 17, 'Code': 'AUT', 'Name': 'Austria'},
#   'Circuit': {'Key': 19, 'ShortName': 'Spielberg'}},
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 9541,
#  'Type': 'Qualifying',
#  'Name': 'Qualifying',
#  'StartDate': datetime.datetime(2024, 6, 29, 16, 0),
#  'EndDate': datetime.datetime(2024, 6, 29, 17, 0),
#  'GmtOffset': datetime.timedelta(seconds=7200),
#  'Path': '2024/2024-06-30_Austrian_Grand_Prix/2024-06-29_Qualifying/'}

# %%
quali.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 4             4      L NORRIS          NOR           norris          McLaren
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 31           31        E OCON          OCO             ocon           Alpine
# 3             3   D RICCIARDO          RIC        ricciardo               RB
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 10           10       P GASLY          GAS            gasly           Alpine
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 23           23       A ALBON          ALB            albon         Williams
# 18           18      L STROLL          STR           stroll     Aston Martin
# 77           77      V BOTTAS          BOT           bottas      Kick Sauber
# 2             2    L SARGEANT          SAR         sargeant         Williams
# 24           24        G ZHOU          ZHO             zhou      Kick Sauber
#
#    TeamColor        TeamId  FirstName    LastName          FullName  ...  \
# 1     3671C6      red_bull        Max  Verstappen    Max Verstappen  ...
# 4     FF8000       mclaren      Lando      Norris      Lando Norris  ...
# 63    27F4D2      mercedes     George     Russell    George Russell  ...
# 55    E80020       ferrari     Carlos       Sainz      Carlos Sainz  ...
# 44    27F4D2      mercedes      Lewis    Hamilton    Lewis Hamilton  ...
# 16    E80020       ferrari    Charles     Leclerc   Charles Leclerc  ...
# 81    FF8000       mclaren      Oscar     Piastri     Oscar Piastri  ...
# 11    3671C6      red_bull     Sergio       Perez      Sergio Perez  ...
# 27    B6BABD          haas       Nico  Hulkenberg   Nico Hulkenberg  ...
# 31    0093cc        alpine    Esteban        Ocon      Esteban Ocon  ...
# 3     6692FF            rb     Daniel   Ricciardo  Daniel Ricciardo  ...
# 20    B6BABD          haas      Kevin   Magnussen   Kevin Magnussen  ...
# 10    0093cc        alpine     Pierre       Gasly      Pierre Gasly  ...
# 22    6692FF            rb       Yuki     Tsunoda      Yuki Tsunoda  ...
# 14    229971  aston_martin   Fernando      Alonso   Fernando Alonso  ...
# 23    64C4FF      williams  Alexander       Albon   Alexander Albon  ...
# 18    229971  aston_martin      Lance      Stroll      Lance Stroll  ...
# 77    52e252        sauber   Valtteri      Bottas   Valtteri Bottas  ...
# 2     64C4FF      williams      Logan    Sargeant    Logan Sargeant  ...
# 24    52e252        sauber     Guanyu        Zhou       Guanyu Zhou  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  \
# 1          NED      1.0                              NaN
# 4          GBR      2.0                              NaN
# 63         GBR      3.0                              NaN
# 55         ESP      4.0                              NaN
# 44         GBR      5.0                              NaN
# 16         MON      6.0                              NaN
# 81         AUS      7.0                              NaN
# 11         MEX      8.0                              NaN
# 27         GER      9.0                              NaN
# 31         FRA     10.0                              NaN
# 3          AUS     11.0                              NaN
# 20         DEN     12.0                              NaN
# 10         FRA     13.0                              NaN
# 22         JPN     14.0                              NaN
# 14         ESP     15.0                              NaN
# 23         THA     16.0                              NaN
# 18         CAN     17.0                              NaN
# 77         FIN     18.0                              NaN
# 2          USA     19.0                              NaN
# 24         CHN     20.0                              NaN
#
#                        Q1                     Q2                     Q3 Time  \
# 1  0 days 00:01:05.336000 0 days 00:01:04.469000 0 days 00:01:04.314000  NaT
# 4  0 days 00:01:05.450000 0 days 00:01:05.103000 0 days 00:01:04.718000  NaT
# 63 0 days 00:01:05.585000 0 days 00:01:05.016000 0 days 00:01:04.840000  NaT
# 55 0 days 00:01:05.263000 0 days 00:01:05.016000 0 days 00:01:04.851000  NaT
# 44 0 days 00:01:05.541000 0 days 00:01:05.053000 0 days 00:01:04.903000  NaT
# 16 0 days 00:01:05.509000 0 days 00:01:05.104000 0 days 00:01:05.044000  NaT
# 3                      NaT 0 days 00:00:40.276000  ...     False
# 4   0 days 00:00:16.421000 0 days 00:00:29.316000  ...     False
# ..                     ...                    ...  ...       ...
# 315 0 days 00:00:16.570000 0 days 00:00:29.397000  ...      True
# 316 0 days 00:00:17.868000 0 days 00:00:32.902000  ...      True
# 317                    NaT 0 days 00:00:38.221000  ...      True
# 318 0 days 00:00:16.580000 0 days 00:00:29.380000  ...      True
# 319 0 days 00:00:26.239000 0 days 00:00:37.028000  ...      True
#
#                 Team           LapStartTime            LapStartDate  \
# 0    Red Bull Racing 0 days 00:13:22.886000 2024-06-29 14:00:04.014
# 1    Red Bull Racing 0 days 00:14:48.685000 2024-06-29 14:01:29.813
# 2    Red Bull Racing 0 days 00:15:54.739000 2024-06-29 14:02:35.867
# 3    Red Bull Racing 0 days 00:17:36.828000 2024-06-29 14:04:17.956
# 4    Red Bull Racing 0 days 00:21:16.857000 2024-06-29 14:07:57.985
# ..               ...                    ...                     ...
# 315      Kick Sauber 0 days 00:23:40.223000 2024-06-29 14:10:21.351
# 316      Kick Sauber 0 days 00:24:46.359000 2024-06-29 14:11:27.487
# 317      Kick Sauber 0 days 00:26:05.592000 2024-06-29 14:12:46.720
# 318      Kick Sauber 0 days 00:29:52.172000 2024-06-29 14:16:33.300
# 319      Kick Sauber 0 days 00:30:58.233000 2024-06-29 14:17:39.361
#
#      TrackStatus  Position  Deleted  DeletedReason  FastF1Generated IsAccurate
# 0              1       NaN    False                           False      False
# 1              1       NaN    False                           False       True
# 2              1       NaN    False                           False      False
# 3              1       NaN    False                           False      False
# 4              1       NaN    False                           False       True
# ..           ...       ...      ...            ...              ...        ...
# 315            1       NaN    False                           False       True
# 316            1       NaN    False                           False      False
# 317            1       NaN    False                           False      False
# 318            1       NaN    False                           False       True
# 319            1       NaN    False                           False      False
#
# [320 rows x 31 columns]

# %%
nor = quali.get_driver('NOR')
nor
# Out:
# DriverNumber                                                          4
# BroadcastName                                                  L NORRIS
# Abbreviation                                                        NOR
# DriverId                                                         norris
# TeamName                                                        McLaren
# TeamColor                                                        FF8000
# TeamId                                                          mclaren
# FirstName                                                         Lando
# LastName                                                         Norris
# FullName                                                   Lando Norris
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         GBR
# Position                                                            2.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:05.450000
# Q2                                               0 days 00:01:05.103000
# Q3                                               0 days 00:01:04.718000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 4, dtype: object

# %%
nor_laps = quali.laps.pick_driver("NOR")
nor_lap_time = nor_laps["LapTime"]
nor_sec1 = nor_laps["Sector1Time"]
nor_sec2 = nor_laps["Sector2Time"]
nor_sec3 = nor_laps["Sector3Time"]
nor_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 18                    NaT                    NaT 0 days 00:00:38.834000
# 19 0 days 00:01:05.910000 0 days 00:00:16.510000 0 days 00:00:29.579000
# 20 0 days 00:01:27.768000 0 days 00:00:22.348000 0 days 00:00:36.415000
# 21                    NaT                    NaT 0 days 00:00:39.794000
# 22 0 days 00:01:05.450000 0 days 00:00:16.356000 0 days 00:00:29.369000
# 23 0 days 00:01:36.284000 0 days 00:00:21.462000 0 days 00:00:38.740000
# 50 0 days 00:00:25.302000    239.0     94.0    288.0    239.0
# 51 0 days 00:00:19.523000    319.0    250.0    285.0    318.0
# 52 0 days 00:00:30.317000    277.0    181.0      NaN    271.0
# 53 0 days 00:00:29.674000    225.0    183.0    287.0    239.0
# 54 0 days 00:00:19.555000    321.0    247.0    286.0    318.0
# 55                    NaT    199.0    170.0      NaN    207.0

# %%
fastest_rus = rus_laps.pick_fastest()
tele_rus = fastest_rus.get_telemetry().add_distance()
tele_rus.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      293      7  11227
# 3      294      7  11002
# 4      296      7  10551
# 5      297      7  10622
# 6      298      7  10693
# ..     ...    ...    ...
# 510    287      7  11654
# 511    289      7  11549
# 512    290      7  10995
# 513    291      7  10441
# 514    291      7  10464
#
# [513 rows x 3 columns]

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 7), height_ratios=[2, 1])

ax[0].plot(tele_max.Distance, tele_max.Speed, label="Verstappen")
ax[0].plot(tele_nor.Distance,tele_nor.Speed,label = "Norris")
ax[0].plot(tele_rus.Distance,tele_rus.Speed,label = "Russel")
ax[0].set_title("Speed vs Distance", fontsize=16)
ax[0].set_xlabel("Distance", fontsize=12)
ax[0].set_ylabel("Speed", fontsize=12)
ax[0].legend(fontsize=10)
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

ax[1].plot(tele_max.Distance, tele_max.Throttle, label="Verstappen")
ax[1].plot(tele_nor.Distance,tele_nor.Throttle,label = "Norris")
ax[1].plot(tele_rus.Distance,tele_rus.Throttle,label = "Russel")
ax[1].set_title("Throttle vs Distance", fontsize=14)
ax[1].set_xlabel("Distance", fontsize=10)
ax[1].set_ylabel("Throttle", fontsize=10)
ax[1].legend(fontsize=8)
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()

# %%
def convert_to_normal(time):
    if pd.isna(time):
        return time 
    
    time_str = str(time)  
    parts = time_str.split()
    
    days = int(parts[0])
    minutes, seconds_with_microseconds = parts[2].split(':')[1:]
    seconds, microseconds = seconds_with_microseconds.split('.')
    
    minutes = int(minutes)
    seconds = int(seconds)
    microseconds = int(microseconds)
    
    total_microseconds = days * 86400000000 + minutes * 60000000 + seconds * 1000000 + microseconds
    
    minutes, remaining_microseconds = divmod(total_microseconds, 60000000)
    seconds, microseconds = divmod(remaining_microseconds, 1000000)
    
    normal_time = f"{minutes:02d}:{seconds:02d}.{microseconds:06d}"
    return normal_time

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Vertappen'] * len(max_sec1),
    'Sector1Time': max_sec1,
    'Sector2Time': max_sec2,
    'Sector3Time': max_sec3,
    'Lap Time' : max_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Norris'] * len(nor_sec1),
    'Sector1Time': nor_sec1,
    'Sector2Time': nor_sec2,
    'Sector3Time': nor_sec3,
    'Lap Time' : nor_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Russel'] * len(rus_sec1),
    'Sector1Time': rus_sec1,
    'Sector2Time': rus_sec2,
    'Sector3Time': rus_sec3,
# 8   Vertappen  00:22.813000  00:37.522000  00:27.939000  01:28.274000
# 55     Russel  00:22.999000  00:39.300000           NaT           NaT
# 43     Russel  00:23.048000  00:37.757000  00:30.980000  01:31.785000
# 49     Russel  00:24.888000  00:39.899000  00:30.596000  01:35.383000
# 24     Norris  00:55.413000  00:39.321000  00:22.275000  01:57.009000
# 18     Norris           NaT  00:38.834000  00:21.752000           NaT
# 41     Russel           NaT  00:38.861000  00:25.441000           NaT
# 12  Vertappen           NaT  00:39.236000  00:25.959000           NaT
# 35     Norris           NaT  00:39.238000  00:23.170000           NaT
# 47     Russel           NaT  00:39.239000  00:25.622000           NaT
# 9   Vertappen           NaT  00:39.580000  00:23.182000           NaT
# 38     Russel           NaT  00:39.666000  00:26.749000           NaT
# 21     Norris           NaT  00:39.794000  00:22.912000           NaT
# 6   Vertappen           NaT  00:40.122000  00:22.728000           NaT
# 3   Vertappen           NaT  00:40.276000  00:23.685000           NaT
# 15  Vertappen           NaT  00:40.344000  00:22.425000           NaT
# 44     Russel           NaT  00:40.414000  00:25.847000           NaT
# 50     Russel           NaT  00:40.688000  00:25.302000           NaT
# 30     Norris           NaT  00:41.116000  00:22.486000           NaT
# 0   Vertappen           NaT  00:41.204000  00:23.217000           NaT
# 32     Norris           NaT  00:41.336000  00:22.339000           NaT
# 27     Norris           NaT  00:42.605000  00:21.282000           NaT
# 53     Russel           NaT  00:43.079000  00:29.674000           NaT

# %% [markdown]
# **Race**

# %%
race = f1.get_session(2024,"Austria","R")
race.load()
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver 12: Car data is incomplete!
# _api        WARNING 	Driver  2: Car data is incomplete!
# _api        WARNING 	Driver  3: Car data is incomplete!
# _api        WARNING 	Driver  4: Car data is incomplete!
# _api        WARNING 	Driver 10: Car data is incomplete!
# _api        WARNING 	Driver 11: Car data is incomplete!
# _api        WARNING 	Driver 14: Car data is incomplete!
# _api        WARNING 	Driver 16: Car data is incomplete!
# _api        WARNING 	Driver 18: Car data is incomplete!
# _api        WARNING 	Driver 20: Car data is incomplete!
# _api        WARNING 	Driver 22: Car data is incomplete!
# _api        WARNING 	Driver 23: Car data is incomplete!
# _api        WARNING 	Driver 27: Car data is incomplete!
# _api        WARNING 	Driver 31: Car data is incomplete!
# _api        WARNING 	Driver 44: Car data is incomplete!
# _api        WARNING 	Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 63: Car data is incomplete!
# _api        WARNING 	Driver 77: Car data is incomplete!
# _api        WARNING 	Driver 81: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 12: Position data is incomplete!
# _api        WARNING 	Driver  2: Position data is incomplete!
# _api        WARNING 	Driver  3: Position data is incomplete!
# _api        WARNING 	Driver  4: Position data is incomplete!
# _api        WARNING 	Driver 10: Position data is incomplete!
# _api        WARNING 	Driver 11: Position data is incomplete!
# _api        WARNING 	Driver 14: Position data is incomplete!
# _api        WARNING 	Driver 16: Position data is incomplete!
# _api        WARNING 	Driver 18: Position data is incomplete!
# _api        WARNING 	Driver 20: Position data is incomplete!
# _api        WARNING 	Driver 22: Position data is incomplete!
# _api        WARNING 	Driver 23: Position data is incomplete!
# _api        WARNING 	Driver 27: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 81: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['63', '81', '55', '44', '1', '27', '11', '20', '3', '10', '16', '31', '18', '22', '23', '77', '24', '14', '2', '4']

# %%
race.results.loc[:,["Abbreviation","TeamName","GridPosition","Position","Time","Status"]]
# Out:
#    Abbreviation         TeamName  GridPosition  Position  \
# 63          RUS         Mercedes           3.0       1.0
# 81          PIA          McLaren           7.0       2.0
# 55          SAI          Ferrari           4.0       3.0
# 44          HAM         Mercedes           5.0       4.0
# 1           VER  Red Bull Racing           1.0       5.0
# 27          HUL     Haas F1 Team           9.0       6.0
# 11          PER  Red Bull Racing           8.0       7.0
# 20          MAG     Haas F1 Team          12.0       8.0
# 3           RIC               RB          11.0       9.0
# 10          GAS           Alpine          13.0      10.0
# 16          LEC          Ferrari           6.0      11.0
# 31          OCO           Alpine          10.0      12.0
# 18          STR     Aston Martin          17.0      13.0
# 22          TSU               RB          14.0      14.0
# 23          ALB         Williams          16.0      15.0
# 77          BOT      Kick Sauber          18.0      16.0
# 24          ZHO      Kick Sauber          20.0      17.0
# 14          ALO     Aston Martin          15.0      18.0
# 2           SAR         Williams          19.0      19.0
# 4           NOR          McLaren           2.0      20.0
#
#                      Time    Status
# 63 0 days 01:24:22.798000  Finished
# 81 0 days 00:00:01.906000  Finished
# 55 0 days 00:00:04.533000  Finished
# 44 0 days 00:00:23.142000  Finished
# 1  0 days 00:00:37.253000  Finished
# 27 0 days 00:00:54.088000  Finished
# 11 0 days 00:00:54.672000  Finished
# 20 0 days 00:01:00.355000  Finished
# 3  0 days 00:01:01.169000  Finished
# 10 0 days 00:01:01.766000  Finished
# 16 0 days 00:01:07.056000  Finished
# 31 0 days 00:01:08.325000  Finished
# 18                    NaT    +1 Lap
# 22                    NaT    +1 Lap
# 23                    NaT    +1 Lap
# 77                    NaT    +1 Lap
# 24                    NaT    +1 Lap
# 14                    NaT    +1 Lap
# 2                     NaT   +2 Laps
# 4                     NaT   +7 Laps

# %%
race.laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 00:56:45.737000    RUS           63 0 days 00:01:14.401000
# 1    0 days 00:57:56.317000    RUS           63 0 days 00:01:10.580000
# 2    0 days 00:59:06.758000    RUS           63 0 days 00:01:10.441000
# 3    0 days 01:00:17.225000    RUS           63 0 days 00:01:10.467000
# 4    0 days 01:01:27.418000    RUS           63 0 days 00:01:10.193000
# ...                     ...    ...          ...                    ...
# 1400 0 days 02:06:32.353000    NOR            4 0 days 00:01:09.356000
# 1401 0 days 02:07:42.390000    NOR            4 0 days 00:01:10.037000
# 1402 0 days 02:08:51.899000    NOR            4 0 days 00:01:09.509000
# 1403 0 days 02:10:02.133000    NOR            4 0 days 00:01:10.234000
# 1404 0 days 02:12:02.390000    NOR            4 0 days 00:02:00.257000
#
#       LapNumber  Stint PitOutTime              PitInTime  \
# 0           1.0    1.0        NaT                    NaT
# 1           2.0    1.0        NaT                    NaT
# 2           3.0    1.0        NaT                    NaT
# 3           4.0    1.0        NaT                    NaT
# 4           5.0    1.0        NaT                    NaT
# ...         ...    ...        ...                    ...
# 1400       60.0    3.0        NaT                    NaT
# 1401       61.0    3.0        NaT                    NaT
# 1402       62.0    3.0        NaT                    NaT
# 1403       63.0    3.0        NaT                    NaT
# 1404       64.0    3.0        NaT 0 days 02:11:58.656000
#
#                 Sector1Time            Sector2Time  ... FreshTyre      Team  \
# 0                       NaT 0 days 00:00:32.359000  ...      True  Mercedes
# 1    0 days 00:00:17.469000 0 days 00:00:31.731000  ...      True  Mercedes
# 2    0 days 00:00:17.801000 0 days 00:00:31.483000  ...      True  Mercedes
# 3    0 days 00:00:17.555000 0 days 00:00:31.631000  ...      True  Mercedes
# 4    0 days 00:00:17.610000 0 days 00:00:31.332000  ...      True  Mercedes
# ...                     ...                    ...  ...       ...       ...
# 1400 0 days 00:00:17.270000 0 days 00:00:31.434000  ...      True   McLaren
# 1401 0 days 00:00:17.086000 0 days 00:00:32.125000  ...      True   McLaren
# 1402 0 days 00:00:17.182000 0 days 00:00:31.527000  ...      True   McLaren
# 1403 0 days 00:00:17.195000 0 days 00:00:32.111000  ...      True   McLaren
# 1404 0 days 00:00:17.309000 0 days 00:00:41.854000  ...      True   McLaren
#
#                LapStartTime            LapStartDate  TrackStatus  Position  \
# 0    0 days 00:55:31.047000 2024-06-30 13:03:02.158            1       3.0
# 1    0 days 00:56:45.737000 2024-06-30 13:04:16.848            1       3.0
# 2    0 days 00:57:56.317000 2024-06-30 13:05:27.428            1       3.0
# 3    0 days 00:59:06.758000 2024-06-30 13:06:37.869            1       3.0
# 4    0 days 01:00:17.225000 2024-06-30 13:07:48.336            1       3.0
# ...                     ...                     ...          ...       ...
# 1400 0 days 02:05:22.997000 2024-06-30 14:12:54.108            1       2.0
# 1401 0 days 02:06:32.353000 2024-06-30 14:14:03.464            1       2.0
# 1402 0 days 02:07:42.390000 2024-06-30 14:15:13.501            1       2.0
# 1403 0 days 02:08:51.899000 2024-06-30 14:16:23.010            1       2.0
# 1404 0 days 02:10:02.133000 2024-06-30 14:17:33.244           12       6.0
#
#       Deleted                   DeletedReason  FastF1Generated IsAccurate
# 0       False                                            False      False
# 1       False                                            False       True
# 2       False                                            False       True
# 3       False                                            False       True
# 4       False                                            False       True
# ...       ...                             ...              ...        ...
# 1400    False                                            False       True
# 1401    False                                            False       True
# 1402    False                                            False       True
# 1403    False                                            False       True
# 1404     True  TRACK LIMITS AT TURN 3 LAP 64             False      False
#
# [1405 rows x 31 columns]

# %%
rus_race = race.laps.pick_driver("RUS")
fastest_lap_rus_race = rus_race.pick_fastest().LapTime
rus_race_lap_time = rus_race["LapTime"]
rus_race_sec1 = rus_race["Sector1Time"]
rus_race_sec2 = rus_race["Sector2Time"]
rus_race_sec3 = rus_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_rus_race),"which was in Lap number",rus_race.pick_fastest().LapNumber)
rus_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:09.164000 which was in Lap number 48.0
#                   LapTime            Sector1Time            Sector2Time  \
# 0  0 days 00:01:14.401000                    NaT 0 days 00:00:32.359000
# 1  0 days 00:01:10.580000 0 days 00:00:17.469000 0 days 00:00:31.731000
# 2  0 days 00:01:10.441000 0 days 00:00:17.801000 0 days 00:00:31.483000
# 3  0 days 00:01:10.467000 0 days 00:00:17.555000 0 days 00:00:31.631000
# 4  0 days 00:01:10.193000 0 days 00:00:17.610000 0 days 00:00:31.332000
# ..                    ...                    ...                    ...
# 66 0 days 00:01:09.352000 0 days 00:00:17.227000 0 days 00:00:31.372000
# 67 0 days 00:01:09.645000 0 days 00:00:17.449000 0 days 00:00:31.317000
# 68 0 days 00:01:09.747000 0 days 00:00:17.500000 0 days 00:00:31.450000
# 69 0 days 00:01:09.627000 0 days 00:00:17.452000 0 days 00:00:31.391000
# 70 0 days 00:01:10.193000 0 days 00:00:17.386000 0 days 00:00:31.580000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 0  0 days 00:00:21.359000    306.0    232.0    271.0    296.0
# 1  0 days 00:00:21.380000    295.0    225.0    272.0    298.0
# 2  0 days 00:00:21.157000    287.0    224.0    271.0    308.0
# 3  0 days 00:00:21.281000    296.0    228.0    271.0    289.0
# 4  0 days 00:00:21.251000    294.0    224.0    270.0    294.0
# ..                    ...      ...      ...      ...      ...
# 66 0 days 00:00:20.753000    317.0    238.0    276.0    308.0
# 67 0 days 00:00:20.879000    294.0    236.0    277.0    305.0
# 68 0 days 00:00:20.797000    299.0    235.0    277.0    309.0
# 69 0 days 00:00:20.784000    301.0    231.0    276.0    307.0
# 70 0 days 00:00:21.227000      NaN    233.0    273.0    307.0
#
# [71 rows x 8 columns]

# %%
fastest_lap_race_rus = rus_race.pick_fastest()
tele_race_rus= fastest_lap_race_rus.get_telemetry().add_distance()
speed_race_rus = tele_race_rus.Speed
tele_race_rus.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      279      7  11469
# 3      279      7  11469
# 4      280      7  11469
# 5      281      7  11543
# 6      283      7  11618
# ..     ...    ...    ...
# 509    273      7  11252
# 510    275      7  11287
# 511    276      7  11355
# 512    277      7  11423
# 513    278      7  11457
#
# [512 rows x 3 columns]

# %%
pia_race = race.laps.pick_driver("PIA")
fastest_lap_pia_race = pia_race.pick_fastest().LapTime
pia_race_lap_time = pia_race["LapTime"]
pia_race_sec1 = pia_race["Sector1Time"]
pia_race_sec2 = pia_race["Sector2Time"]
pia_race_sec3 = pia_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_pia_race),"which was in Lap number",pia_race.pick_fastest().LapNumber)
pia_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:08.697000 which was in Lap number 56.0
#                    LapTime            Sector1Time            Sector2Time  \
# 71  0 days 00:01:16.950000                    NaT 0 days 00:00:33.184000
# 72  0 days 00:01:10.541000 0 days 00:00:17.600000 0 days 00:00:31.425000
# 73  0 days 00:01:10.743000 0 days 00:00:17.362000 0 days 00:00:31.679000
# 74  0 days 00:01:10.810000 0 days 00:00:17.539000 0 days 00:00:31.572000
# 75  0 days 00:01:10.607000 0 days 00:00:17.340000 0 days 00:00:31.678000
# ..                     ...                    ...                    ...
# 137 0 days 00:01:09.532000 0 days 00:00:17.445000 0 days 00:00:31.369000
# 138 0 days 00:01:09.241000 0 days 00:00:17.356000 0 days 00:00:31.174000
# 139 0 days 00:01:09.159000 0 days 00:00:17.490000 0 days 00:00:30.993000
# 140 0 days 00:01:09.989000 0 days 00:00:17.756000 0 days 00:00:31.444000
# 141 0 days 00:01:09.668000 0 days 00:00:17.548000 0 days 00:00:31.324000
#
#                Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 71  0 days 00:00:21.730000    312.0    222.0    270.0    300.0
# 72  0 days 00:00:21.516000      NaN    227.0    277.0    306.0
# 73  0 days 00:00:21.702000    318.0    226.0    278.0    308.0
# 74  0 days 00:00:21.699000    309.0    225.0    276.0    302.0
# 75  0 days 00:00:21.589000    316.0    229.0    277.0    307.0
# ..                     ...      ...      ...      ...      ...
# 137 0 days 00:00:20.718000    289.0    231.0    277.0    299.0
# 138 0 days 00:00:20.711000    308.0    234.0    276.0    297.0
# 139 0 days 00:00:20.676000    295.0    234.0    278.0    303.0
# 140 0 days 00:00:20.789000    299.0    229.0    274.0    307.0
# 141 0 days 00:00:20.796000    295.0    232.0    275.0    306.0
#
# [71 rows x 8 columns]

# %%
fastest_lap_race_pia = pia_race.pick_fastest()
tele_race_pia= fastest_lap_race_pia.get_telemetry().add_distance()
speed_race_pia = tele_race_pia.Speed
tele_race_pia.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      280      7  11257
# 3      281      7  11301
# 4      282      7  11340
# 5      283      7  11380
# 6      287      7  11533
# ..     ...    ...    ...
# 532    276      7  11089
# 533    278      7  11144
# 534    280      7  11200
# 535    281      7  11230
# 536    281      7  11245
#
# [535 rows x 3 columns]

# %%
max_race = race.laps.pick_driver("VER")
fastest_lap_max_race = max_race.pick_fastest().LapTime
max_race_lap_time = max_race["LapTime"]
max_race_sec1 = max_race["Sector1Time"]
max_race_sec2 = max_race["Sector2Time"]
max_race_sec3 = max_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_max_race),"which was in Lap number",max_race.pick_fastest().LapNumber)
max_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:07.719000 which was in Lap number 68.0
#                    LapTime            Sector1Time            Sector2Time  \
# 284 0 days 00:01:12.050000                    NaT 0 days 00:00:31.028000
# 285 0 days 00:01:09.938000 0 days 00:00:17.697000 0 days 00:00:31.186000
# 286 0 days 00:01:09.857000 0 days 00:00:17.531000 0 days 00:00:31.065000
# 287 0 days 00:01:09.903000 0 days 00:00:17.571000 0 days 00:00:31.180000
# 288 0 days 00:01:10.005000 0 days 00:00:17.674000 0 days 00:00:31.153000
# ..                     ...                    ...                    ...
# 350 0 days 00:01:11.691000 0 days 00:00:17.347000 0 days 00:00:32.344000
# 351 0 days 00:01:07.719000 0 days 00:00:17.142000 0 days 00:00:30.279000
# 352 0 days 00:01:08.321000 0 days 00:00:17.252000 0 days 00:00:30.674000
# 353 0 days 00:01:08.072000 0 days 00:00:17.214000 0 days 00:00:30.512000
# 354 0 days 00:01:08.518000 0 days 00:00:17.243000 0 days 00:00:30.640000
#
#                Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 284 0 days 00:00:20.960000    300.0    229.0    270.0    291.0
# 285 0 days 00:00:21.055000    290.0    227.0    270.0    286.0
# 286 0 days 00:00:21.261000    292.0    230.0    268.0    286.0
# 287 0 days 00:00:21.152000    293.0    230.0    270.0    289.0
# 288 0 days 00:00:21.178000      NaN    230.0    270.0    291.0
# ..                     ...      ...      ...      ...      ...
# 350        0 days 00:00:22    286.0    213.0    277.0    290.0
# 351 0 days 00:00:20.298000    297.0    239.0    278.0    307.0
# 352 0 days 00:00:20.395000    289.0    235.0    277.0    298.0
# 353 0 days 00:00:20.346000    290.0    238.0    277.0    296.0
# 354 0 days 00:00:20.635000    288.0    238.0    249.0    298.0
#
# [71 rows x 8 columns]

# %%
fastest_lap_race_max = max_race.pick_fastest()
tele_race_max= fastest_lap_race_max.get_telemetry().add_distance()
speed_race_max = tele_race_max.Speed
tele_race_max.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      281      7  11134
# 3      282      7  11134
# 4      283      7  11134
# 5      284      7  11236
# 6      285      7  11300
# ..     ...    ...    ...
# 515    279      7  11098
# 516    280      7  11141
# 517    281      7  11185
# 518    283      7  11229
# 519    284      7  11292
#
# [518 rows x 3 columns]

# %%
hul_race = race.laps.pick_driver("HUL")
fastest_lap_hul_race = hul_race.pick_fastest().LapTime
hul_race_lap_time = hul_race["LapTime"]
hul_race_sec1 = hul_race["Sector1Time"]
hul_race_sec2 = hul_race["Sector2Time"]
hul_race_sec3 = hul_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_hul_race),"which was in Lap number",hul_race.pick_fastest().LapNumber)
hul_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:10.215000 which was in Lap number 51.0
#                    LapTime            Sector1Time            Sector2Time  \
# 355 0 days 00:01:18.420000                    NaT 0 days 00:00:33.185000
# 356 0 days 00:01:10.217000 0 days 00:00:17.533000 0 days 00:00:31.155000
# 357 0 days 00:01:10.609000 0 days 00:00:17.460000 0 days 00:00:31.698000
# 358 0 days 00:01:10.958000 0 days 00:00:17.653000 0 days 00:00:31.601000
# 359 0 days 00:01:11.026000 0 days 00:00:17.692000 0 days 00:00:31.757000
# ..                     ...                    ...                    ...
# 421 0 days 00:01:11.076000 0 days 00:00:17.567000 0 days 00:00:32.095000
# 422 0 days 00:01:10.567000 0 days 00:00:17.478000 0 days 00:00:31.899000
# 423 0 days 00:01:10.341000 0 days 00:00:17.406000 0 days 00:00:31.758000
# 424 0 days 00:01:10.689000 0 days 00:00:17.456000 0 days 00:00:31.624000
# 425 0 days 00:01:11.633000 0 days 00:00:18.201000 0 days 00:00:32.031000
#
#                Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 355 0 days 00:00:22.475000    307.0    221.0    271.0    300.0
# 356 0 days 00:00:21.529000    315.0    226.0    274.0    325.0
# 357 0 days 00:00:21.451000    310.0    227.0    275.0    292.0
# 358 0 days 00:00:21.704000    296.0    228.0    273.0    295.0
# 359 0 days 00:00:21.577000    298.0    226.0    273.0    292.0
# ..                     ...      ...      ...      ...      ...
# 421 0 days 00:00:21.414000    287.0    223.0    274.0    295.0
# 422 0 days 00:00:21.190000    301.0    226.0    276.0    299.0
# 423 0 days 00:00:21.177000    300.0    224.0    275.0    296.0
# 424 0 days 00:00:21.609000    291.0    226.0    263.0    299.0
# 425 0 days 00:00:21.401000    289.0    228.0    273.0    322.0
#
# [71 rows x 8 columns]

# %%
fastest_lap_race_hul = hul_race.pick_fastest()
tele_race_hul= fastest_lap_race_hul.get_telemetry().add_distance()
speed_race_hul = tele_race_hul.Speed
tele_race_hul.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      287      7  11507
# 3      289      7  11550
# 4      292      7  11635
# 5      292      7  11688
# 6      293      7  11742
# ..     ...    ...    ...
# 537    275      7  11031
# 538    277      7  11089
# 539    279      7  11147
# 540    280      7  11215
# 541    280      7  11249
#
# [540 rows x 3 columns]

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 7), height_ratios=[2, 1])

ax[0].plot(tele_race_max.Distance, tele_race_max.Speed, label="Verstappen")
ax[0].plot(tele_race_pia.Distance,tele_race_pia.Speed,label = "Piastri")
ax[0].plot(tele_race_rus.Distance,tele_race_rus.Speed,label = "Russel")
ax[0].plot(tele_race_hul.Distance,tele_race_hul.Speed,label = "Hulkenberg")
ax[0].set_title("Speed vs Distance", fontsize=16)
ax[0].set_xlabel("Distance", fontsize=12)
ax[0].set_ylabel("Speed", fontsize=12)
ax[0].legend(fontsize=10)
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

ax[1].plot(tele_race_max.Distance, tele_race_max.Throttle, label="Verstappen")
ax[1].plot(tele_race_pia.Distance,tele_race_pia.Throttle,label = "Piastri")
ax[1].plot(tele_race_rus.Distance,tele_race_rus.Throttle,label = "Russel")
ax[1].plot(tele_race_hul.Distance,tele_race_hul.Throttle,label = "Hulkenberg")
ax[1].set_title("Throttle vs Distance", fontsize=14)
ax[1].set_xlabel("Distance", fontsize=10)
ax[1].set_ylabel("Throttle", fontsize=10)
ax[1].legend(fontsize=8)
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Norris'] * len(rus_race_sec1),
    'Sector1Time': rus_race_sec1,
    'Sector2Time': rus_race_sec2,
    'Sector3Time': rus_race_sec3,
    'Lap Time' : rus_race_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Verstappen'] * len(max_race_sec1),
    'Sector1Time': max_race_sec1,
    'Sector2Time': max_race_sec2,
    'Sector3Time': max_race_sec3,
    'Lap Time' : max_race_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Hamilton'] * len(pia_race_sec1),
    'Sector1Time': pia_race_sec1,
    'Sector2Time': pia_race_sec2,
    'Sector3Time': pia_race_sec3,
    'Lap Time' : pia_race_lap_time
})

driver4_sectors = pd.DataFrame({
    'Driver': ['Hamilton'] * len(hul_race_sec1),
    'Sector1Time': hul_race_sec1,
    'Sector2Time': hul_race_sec2,
    'Sector3Time': hul_race_sec3,
    'Lap Time' : hul_race_lap_time
})


all_drivers_sectors = pd.concat([driver1_sectors, driver2_sectors, driver3_sectors, driver4_sectors], ignore_index=True)
all_drivers_sectors['Sector1Time'] = all_drivers_sectors['Sector1Time'].apply(convert_to_normal)
all_drivers_sectors['Sector2Time'] = all_drivers_sectors['Sector2Time'].apply(convert_to_normal)
# all_drivers_sectors['Sector3Time'] = all_drivers_sectors['Sector3Time'].apply(convert_to_normal)
all_drivers_sectors['Lap Time'] = all_drivers_sectors['Lap Time'].apply(convert_to_normal)
all_drivers_sectors.sort_values(by=["Sector1Time","Sector2Time","Sector3Time"],ascending=True)
# Out:
#          Driver   Sector1Time   Sector2Time            Sector3Time  \
# 126  Verstappen  00:16.933000  00:31.024000 0 days 00:00:20.666000
# 138  Verstappen  00:17.142000  00:30.279000 0 days 00:00:20.298000
# 204    Hamilton  00:17.142000  00:31.754000 0 days 00:00:21.090000
# 206    Hamilton  00:17.197000  00:31.995000 0 days 00:00:20.948000
# 124  Verstappen  00:17.201000  00:31.013000 0 days 00:00:20.575000
# ..          ...           ...           ...                    ...
# 122  Verstappen  00:38.994000  00:31.904000 0 days 00:00:20.687000
# 71   Verstappen           NaT  00:31.028000 0 days 00:00:20.960000
# 0        Norris           NaT  00:32.359000 0 days 00:00:21.359000
# 142    Hamilton           NaT  00:33.184000 0 days 00:00:21.730000
# 213    Hamilton           NaT  00:33.185000 0 days 00:00:22.475000
#
#          Lap Time
# 126  01:08.623000
# 138  01:07.719000
# 204  01:09.986000
# 206  01:10.140000
# 124  01:08.789000
# ..            ...
# 122  01:31.585000
# 71   01:12.050000
# 0    01:14.401000
# 142  01:16.950000
# 213  01:18.420000
#
# [284 rows x 5 columns]

# %%
res = race.results
drivers = res['Abbreviation'].tolist()
fastest_speed = pd.DataFrame(columns=['Driver', 'Speed'])
for i in drivers:
    tele = race.laps.pick_driver(i)
    speed = tele.SpeedST.max()
    df = pd.DataFrame({'Driver': [i], 'Speed': [speed]})
    fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
fastest_speed.sort_values(by="Speed",ascending=True)
# Out:
# /tmp/ipykernel_33303/2770152713.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
#    Driver  Speed
# 4     VER  307.0
# 16    ZHO  311.0
# 2     SAI  313.0
# 3     HAM  315.0
# 19    NOR  316.0
# 15    BOT  317.0
# 1     PIA  318.0
# 13    TSU  320.0
# 12    STR  320.0
# 11    OCO  321.0
# 0     RUS  321.0
# 18    SAR  321.0
# 7     MAG  321.0
# 8     RIC  322.0
# 9     GAS  322.0
# 14    ALB  323.0
# 17    ALO  323.0
# 10    LEC  323.0
# 6     PER  324.0
# 5     HUL  325.0

# %%
fig,ax = plt.subplots(figsize=(18, 6))


bars = ax.bar(fastest_speed['Driver'], fastest_speed['Speed'])

ax.set_xlabel('Drivers')

ax.set_ylabel('Speed')

ax.set_title('Maximum Speeds of Drivers')

plt.xticks(rotation=45, ha='right')

y_min = 275
y_max = np.ceil(fastest_speed['Speed'].max() / 5) * 5 + 5
y_ticks = np.arange(y_min, y_max, 5)
ax.set_ylim(y_min, y_max)
ax.set_yticks(y_ticks)

for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.2f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

# Display the plot
plt.show()
