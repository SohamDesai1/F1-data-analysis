# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fastf1 as f1

# %%
f1.Cache.enable_cache('../cache')

# %% [markdown]
# # Spanish Grand Prix 2024

# %%
quali = f1.get_session(2024,"Spain","Qualifying")
quali.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Qualifying [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '44', '63', '16', '55', '10', '11', '31', '81', '14', '77', '27', '18', '24', '20', '22', '3', '23', '2']

# %%
quali.session_info
# Out:
# {'Meeting': {'Key': 1238,
#   'Name': 'Spanish Grand Prix',
#   'OfficialName': 'FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2024',
#   'Location': 'Barcelona',
#   'Country': {'Key': 1, 'Code': 'ESP', 'Name': 'Spain'},
#   'Circuit': {'Key': 15, 'ShortName': 'Catalunya'}},
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 9535,
#  'Type': 'Qualifying',
#  'Name': 'Qualifying',
#  'StartDate': datetime.datetime(2024, 6, 22, 16, 0),
#  'EndDate': datetime.datetime(2024, 6, 22, 17, 0),
#  'GmtOffset': datetime.timedelta(seconds=7200),
#  'Path': '2024/2024-06-23_Spanish_Grand_Prix/2024-06-22_Qualifying/'}

# %%
quali.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 4             4      L NORRIS          NOR           norris          McLaren
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 10           10       P GASLY          GAS            gasly           Alpine
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 31           31        E OCON          OCO             ocon           Alpine
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 77           77      V BOTTAS          BOT           bottas      Kick Sauber
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 18           18      L STROLL          STR           stroll     Aston Martin
# 24           24        G ZHOU          ZHO             zhou      Kick Sauber
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# 3             3   D RICCIARDO          RIC        ricciardo               RB
# 23           23       A ALBON          ALB            albon         Williams
# 2             2    L SARGEANT          SAR         sargeant         Williams
#
#    TeamColor        TeamId  FirstName    LastName          FullName  ...  \
# 4     FF8000       mclaren      Lando      Norris      Lando Norris  ...
# 1     3671C6      red_bull        Max  Verstappen    Max Verstappen  ...
# 44    27F4D2      mercedes      Lewis    Hamilton    Lewis Hamilton  ...
# 63    27F4D2      mercedes     George     Russell    George Russell  ...
# 16    E80020       ferrari    Charles     Leclerc   Charles Leclerc  ...
# 55    E80020       ferrari     Carlos       Sainz      Carlos Sainz  ...
# 10    0093cc        alpine     Pierre       Gasly      Pierre Gasly  ...
# 11    3671C6      red_bull     Sergio       Perez      Sergio Perez  ...
# 31    0093cc        alpine    Esteban        Ocon      Esteban Ocon  ...
# 81    FF8000       mclaren      Oscar     Piastri     Oscar Piastri  ...
# 14    229971  aston_martin   Fernando      Alonso   Fernando Alonso  ...
# 77    52e252        sauber   Valtteri      Bottas   Valtteri Bottas  ...
# 27    B6BABD          haas       Nico  Hulkenberg   Nico Hulkenberg  ...
# 18    229971  aston_martin      Lance      Stroll      Lance Stroll  ...
# 24    52e252        sauber     Guanyu        Zhou       Guanyu Zhou  ...
# 20    B6BABD          haas      Kevin   Magnussen   Kevin Magnussen  ...
# 22    6692FF            rb       Yuki     Tsunoda      Yuki Tsunoda  ...
# 3     6692FF            rb     Daniel   Ricciardo  Daniel Ricciardo  ...
# 23    64C4FF      williams  Alexander       Albon   Alexander Albon  ...
# 2     64C4FF      williams      Logan    Sargeant    Logan Sargeant  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  \
# 4          GBR      1.0                              NaN
# 1          NED      2.0                              NaN
# 44         GBR      3.0                              NaN
# 63         GBR      4.0                              NaN
# 16         MON      5.0                              NaN
# 55         ESP      6.0                              NaN
# 10         FRA      7.0                              NaN
# 11         MEX      8.0                              NaN
# 31         FRA      9.0                              NaN
# 81         AUS     10.0                              NaN
# 14         ESP     11.0                              NaN
# 77         FIN     12.0                              NaN
# 27         GER     13.0                              NaN
# 18         CAN     14.0                              NaN
# 24         CHN     15.0                              NaN
# 20         DEN     16.0                              NaN
# 22         JPN     17.0                              NaN
# 3          AUS     18.0                              NaN
# 23         THA     19.0                              NaN
# 2          USA     20.0                              NaN
#
#                        Q1                     Q2                     Q3 Time  \
# 4  0 days 00:01:12.386000 0 days 00:01:11.872000 0 days 00:01:11.383000  NaT
# 1  0 days 00:01:12.306000 0 days 00:01:11.653000 0 days 00:01:11.403000  NaT
# 44 0 days 00:01:12.143000 0 days 00:01:11.792000 0 days 00:01:11.701000  NaT
# 63 0 days 00:01:12.456000 0 days 00:01:11.812000 0 days 00:01:11.703000  NaT
# 16 0 days 00:01:12.257000 0 days 00:01:12.038000 0 days 00:01:11.731000  NaT
# 55 0 days 00:01:12.403000 0 days 00:01:11.874000 0 days 00:01:11.736000  NaT
# 10 0 days 00:01:12.651000 0 days 00:01:12.079000 0 days 00:01:11.857000  NaT
# 11 0 days 00:01:12.477000 0 days 00:01:12.054000 0 days 00:01:12.061000  NaT
# 31 0 days 00:01:12.691000 0 days 00:01:12.109000 0 days 00:01:12.125000  NaT
# 81 0 days 00:01:12.460000 0 days 00:01:12.011000                    NaT  NaT
# 14 0 days 00:01:12.505000 0 days 00:01:12.128000                    NaT  NaT
# 77 0 days 00:01:12.758000 0 days 00:01:12.227000                    NaT  NaT
# 27 0 days 00:01:12.708000 0 days 00:01:12.310000                    NaT  NaT
# 18 0 days 00:01:12.881000 0 days 00:01:12.372000                    NaT  NaT
# 24 0 days 00:01:12.880000 0 days 00:01:12.738000                    NaT  NaT
# 20 0 days 00:01:12.937000                    NaT                    NaT  NaT
# 22 0 days 00:01:12.985000                    NaT                    NaT  NaT
# 3  0 days 00:01:13.075000                    NaT                    NaT  NaT
# 23 0 days 00:01:13.153000                    NaT                    NaT  NaT
# 2  0 days 00:01:13.509000                    NaT                    NaT  NaT
#
#    Status Points
# 4            NaN
# 1            NaN
# 44           NaN
# 63           NaN
# 16           NaN
# 55           NaN
# 10           NaN
# 11           NaN
# 31           NaN
# 81           NaN
# 14           NaN
# 77           NaN
# 27           NaN
# 18           NaN
# 24           NaN
# 20           NaN
# 22           NaN
# 3            NaN
# 23           NaN
# 2            NaN
#
# [20 rows x 21 columns]

# %%
quali.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:20:31.873000    NOR            4                    NaT
# 1   0 days 00:21:44.259000    NOR            4 0 days 00:01:12.386000
# 2   0 days 00:23:24.351000    NOR            4 0 days 00:01:40.092000
# 3   0 days 00:45:41.347000    NOR            4                    NaT
# 4   0 days 00:46:53.219000    NOR            4 0 days 00:01:11.872000
# ..                     ...    ...          ...                    ...
# 252 0 days 00:24:30.186000    SAR            2 0 days 00:01:13.810000
# 253 0 days 00:26:48.965000    SAR            2 0 days 00:02:18.779000
# 254 0 days 00:31:13.145000    SAR            2                    NaT
# 255 0 days 00:32:26.654000    SAR            2 0 days 00:01:13.509000
# 256 0 days 00:34:01.460000    SAR            2 0 days 00:01:34.806000
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# 0          1.0    1.0 0 days 00:18:42.073000                    NaT
# 1          2.0    1.0                    NaT                    NaT
# 2          3.0    1.0                    NaT 0 days 00:23:21.511000
# 3          4.0    2.0 0 days 00:43:45.157000                    NaT
# 4          5.0    2.0                    NaT                    NaT
# ..         ...    ...                    ...                    ...
# 252        5.0    2.0                    NaT                    NaT
# 253        6.0    2.0                    NaT 0 days 00:25:57.099000
# 254        7.0    3.0 0 days 00:29:24.771000                    NaT
# 255        8.0    3.0                    NaT                    NaT
# 256        9.0    3.0                    NaT 0 days 00:33:58.634000
#
#                Sector1Time            Sector2Time  ... FreshTyre      Team  \
# 0                      NaT 0 days 00:00:37.675000  ...      True   McLaren
# 1   0 days 00:00:21.579000 0 days 00:00:28.941000  ...      True   McLaren
# 2   0 days 00:00:29.738000 0 days 00:00:38.386000  ...      True   McLaren
# 3                      NaT 0 days 00:00:38.634000  ...      True   McLaren
# 4   0 days 00:00:21.455000 0 days 00:00:28.691000  ...      True   McLaren
# ..                     ...                    ...  ...       ...       ...
# 252 0 days 00:00:21.952000 0 days 00:00:29.504000  ...      True  Williams
# 253 0 days 00:00:25.194000 0 days 00:00:34.380000  ...      True  Williams
# 254                    NaT 0 days 00:00:38.777000  ...      True  Williams
# 255 0 days 00:00:21.853000 0 days 00:00:29.410000  ...      True  Williams
# 256 0 days 00:00:26.971000 0 days 00:00:34.998000  ...      True  Williams
#
#               LapStartTime            LapStartDate  TrackStatus  Position  \
# 0   0 days 00:18:42.073000 2024-06-22 14:05:14.990            1       NaN
# 1   0 days 00:20:31.873000 2024-06-22 14:07:04.790            1       NaN
# 2   0 days 00:21:44.259000 2024-06-22 14:08:17.176            1       NaN
# 3   0 days 00:23:24.351000 2024-06-22 14:09:57.268            1       NaN
# 4   0 days 00:45:41.347000 2024-06-22 14:32:14.264            1       NaN
# ..                     ...                     ...          ...       ...
# 252 0 days 00:23:16.376000 2024-06-22 14:09:49.293            1       NaN
# 253 0 days 00:24:30.186000 2024-06-22 14:11:03.103            1       NaN
# 254 0 days 00:26:48.965000 2024-06-22 14:13:21.882            1       NaN
# 255 0 days 00:31:13.145000 2024-06-22 14:17:46.062            1       NaN
# 256 0 days 00:32:26.654000 2024-06-22 14:18:59.571            1       NaN
#
#      Deleted  DeletedReason  FastF1Generated IsAccurate
# 0      False                           False      False
# 1      False                           False       True
# 2      False                           False      False
# 3      False                           False      False
# 4      False                           False       True
# ..       ...            ...              ...        ...
# 252    False                           False       True
# 253    False                           False      False
# 254    False                           False      False
# 255    False                           False       True
# 256    False                           False      False
#
# [257 rows x 31 columns]

# %%
nor = quali.get_driver('NOR')
nor
# Out:
# DriverNumber                                                          4
# BroadcastName                                                  L NORRIS
# Abbreviation                                                        NOR
# DriverId                                                         norris
# TeamName                                                        McLaren
# TeamColor                                                        FF8000
# TeamId                                                          mclaren
# FirstName                                                         Lando
# LastName                                                         Norris
# FullName                                                   Lando Norris
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         GBR
# Position                                                            1.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:12.386000
# Q2                                               0 days 00:01:11.872000
# Q3                                               0 days 00:01:11.383000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 4, dtype: object

# %%
nor_laps = quali.laps.pick_driver("NOR")
nor_lap_time = nor_laps["LapTime"]
nor_sec1 = nor_laps["Sector1Time"]
nor_sec2 = nor_laps["Sector2Time"]
nor_sec3 = nor_laps["Sector3Time"]
nor_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 0                     NaT                    NaT 0 days 00:00:37.675000
# 1  0 days 00:01:12.386000 0 days 00:00:21.579000 0 days 00:00:28.941000
# 2  0 days 00:01:40.092000 0 days 00:00:29.738000 0 days 00:00:38.386000
# 3                     NaT                    NaT 0 days 00:00:38.634000
# 4  0 days 00:01:11.872000 0 days 00:00:21.455000 0 days 00:00:28.691000
# 5  0 days 00:02:10.664000 0 days 00:00:27.774000 0 days 00:00:37.208000
# 6                     NaT                    NaT 0 days 00:00:39.494000
# 7  0 days 00:01:11.796000 0 days 00:00:21.463000 0 days 00:00:28.592000
# 8  0 days 00:01:36.560000 0 days 00:00:27.389000 0 days 00:00:36.987000
# 9                     NaT                    NaT 0 days 00:00:39.279000
# 10 0 days 00:01:11.383000 0 days 00:00:21.383000 0 days 00:00:28.402000
# 11 0 days 00:01:51.195000 0 days 00:00:30.381000 0 days 00:00:39.977000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 0  0 days 00:00:28.327000    205.0    248.0    291.0     99.0
# 1  0 days 00:00:21.866000    289.0    303.0    289.0    323.0
# 2  0 days 00:00:31.968000    178.0    196.0      NaN    222.0
# 3  0 days 00:00:29.825000    204.0    210.0    292.0    168.0
# 4  0 days 00:00:21.726000    290.0    307.0    286.0    325.0
# 5  0 days 00:01:05.682000    203.0    192.0      NaN    260.0
# 6  0 days 00:00:27.187000    186.0    202.0    292.0    118.0
# 7  0 days 00:00:21.741000    288.0    303.0    291.0    323.0
# 8  0 days 00:00:32.184000    202.0    173.0      NaN    276.0
# 9  0 days 00:00:31.046000    225.0    196.0    294.0    102.0
# 10 0 days 00:00:21.598000    287.0    306.0    288.0    323.0
# 11 0 days 00:00:40.837000    158.0    152.0      NaN    244.0

# %%
fastest_nor = nor_laps.pick_fastest()
tele_nor = fastest_nor.get_telemetry().add_distance()
tele_nor.loc[:,["Speed","nGear","RPM"]]
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#      Speed  nGear    RPM
# 2      300      8  10613
# 3      301      8  10635
# 4      302      8  10676
# 5      303      8  10717
# 6      306      8  10765
# ..     ...    ...    ...
# 545    286      7  11449
# 546    287      7  11485
# 547    289      7  11352
# 548    292      7  11219
# 549    292      7  10995
#
# [548 rows x 3 columns]

# %%
ver = quali.get_driver('VER')
ver
# Out:
# DriverNumber                                                          1
# BroadcastName                                              M VERSTAPPEN
# Abbreviation                                                        VER
# DriverId                                                 max_verstappen
# TeamName                                                Red Bull Racing
# TeamColor                                                        3671C6
# TeamId                                                         red_bull
# FirstName                                                           Max
# LastName                                                     Verstappen
# FullName                                                 Max Verstappen
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         NED
# Position                                                            2.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:12.306000
# Q2                                               0 days 00:01:11.653000
# Q3                                               0 days 00:01:11.403000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 1, dtype: object

# %%
max_laps = quali.laps.pick_driver("VER")
max_lap_time = max_laps["LapTime"]
max_sec1 = max_laps["Sector1Time"]
max_sec2 = max_laps["Sector2Time"]
max_sec3 = max_laps["Sector3Time"]
max_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 12                    NaT                    NaT 0 days 00:00:40.931000
# 13 0 days 00:01:12.306000 0 days 00:00:21.680000 0 days 00:00:28.887000
# 14 0 days 00:01:42.809000 0 days 00:00:29.797000 0 days 00:00:42.484000
# 15                    NaT                    NaT 0 days 00:00:37.176000
# 16 0 days 00:01:11.653000 0 days 00:00:21.520000 0 days 00:00:28.553000
# 17 0 days 00:01:35.627000 0 days 00:00:27.350000 0 days 00:00:36.626000
# 18                    NaT                    NaT 0 days 00:00:40.293000
# 19 0 days 00:01:11.673000 0 days 00:00:21.527000 0 days 00:00:28.595000
# 20 0 days 00:01:38.172000 0 days 00:00:28.860000 0 days 00:00:38.176000
# 21                    NaT                    NaT 0 days 00:00:40.264000
# 22 0 days 00:01:11.403000 0 days 00:00:21.369000 0 days 00:00:28.541000
# 23                    NaT 0 days 00:00:27.790000 0 days 00:00:38.104000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 12 0 days 00:00:25.920000    270.0    242.0    291.0    159.0
# 13 0 days 00:00:21.739000    290.0    309.0    291.0    320.0
# 14 0 days 00:00:30.528000    169.0    162.0      NaN    237.0
# 15 0 days 00:00:24.866000    146.0    249.0    294.0    157.0
# 16 0 days 00:00:21.580000    290.0    311.0    291.0    324.0
# 17 0 days 00:00:31.651000    199.0    199.0      NaN    250.0
# 18 0 days 00:00:25.394000    175.0    233.0    293.0    111.0
# 19 0 days 00:00:21.551000    291.0    310.0    295.0    320.0
# 20 0 days 00:00:31.136000    215.0    218.0      NaN    257.0
# 21 0 days 00:00:25.316000    204.0    169.0    296.0     74.0
# 22 0 days 00:00:21.493000    289.0    310.0    295.0    328.0
# 23                    NaT    203.0    188.0      NaN    251.0

# %%
fastest_max = max_laps.pick_fastest()
tele_max = fastest_max.get_telemetry().add_distance()
tele_max.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      300      8  10758
# 3      301      8  10773
# 4      302      8  10803
# 5      305      8  10884
# 6      306      8  10928
# ..     ...    ...    ...
# 547    295      7  11675
# 548    297      7  11777
# 549    298      7  11817
# 550    299      7  11857
# 551    300      7  11866
#
# [550 rows x 3 columns]

# %%
ham = quali.get_driver('HAM')
ham
# Out:
# DriverNumber                                                         44
# BroadcastName                                                L HAMILTON
# Abbreviation                                                        HAM
# DriverId                                                       hamilton
# TeamName                                                       Mercedes
# TeamColor                                                        27F4D2
# TeamId                                                         mercedes
# FirstName                                                         Lewis
# LastName                                                       Hamilton
# FullName                                                 Lewis Hamilton
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         GBR
# Position                                                            3.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:12.143000
# Q2                                               0 days 00:01:11.792000
# Q3                                               0 days 00:01:11.701000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 44, dtype: object

# %%
ham_laps = quali.laps.pick_driver("HAM")
ham_lap_time = ham_laps["LapTime"]
ham_sec1 = ham_laps["Sector1Time"]
ham_sec2 = ham_laps["Sector2Time"]
ham_sec3 = ham_laps["Sector3Time"]
ham_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 24                    NaT                    NaT 0 days 00:00:36.330000
# 25 0 days 00:01:13.033000 0 days 00:00:21.812000 0 days 00:00:29.222000
# 26 0 days 00:01:45.965000 0 days 00:00:30.820000 0 days 00:00:40.839000
# 27                    NaT                    NaT 0 days 00:00:37.153000
# 28 0 days 00:01:12.143000 0 days 00:00:21.516000 0 days 00:00:28.691000
# 29 0 days 00:01:40.122000 0 days 00:00:28.081000 0 days 00:00:40.713000
# 30                    NaT                    NaT 0 days 00:00:34.853000
# 31 0 days 00:01:12.666000 0 days 00:00:21.544000 0 days 00:00:29.013000
# 32 0 days 00:01:29.256000 0 days 00:00:23.890000 0 days 00:00:32.897000
# 33                    NaT 0 days 00:01:39.110000 0 days 00:00:36.447000
# 34 0 days 00:01:11.792000 0 days 00:00:21.456000 0 days 00:00:28.677000
# 35 0 days 00:01:37.456000 0 days 00:00:27.609000 0 days 00:00:37.323000
# 36                    NaT                    NaT 0 days 00:00:37.905000
# 37 0 days 00:01:11.816000 0 days 00:00:21.475000 0 days 00:00:28.632000
# 38 0 days 00:01:25.168000 0 days 00:00:24.493000 0 days 00:00:32.203000
# 39                    NaT                    NaT 0 days 00:00:39.435000
# 40 0 days 00:01:11.701000 0 days 00:00:21.459000 0 days 00:00:28.543000
# 41                    NaT 0 days 00:00:28.689000 0 days 00:00:41.045000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 24 0 days 00:00:30.947000    218.0    226.0    284.0     81.0
# 25 0 days 00:00:21.999000    290.0    308.0    292.0    322.0
# 26 0 days 00:00:34.306000    133.0    240.0      NaN    307.0
# 27 0 days 00:00:29.961000    228.0    149.0    288.0    186.0
# 28 0 days 00:00:21.936000    291.0    308.0    294.0    323.0
# 29 0 days 00:00:31.328000    206.0    202.0      NaN    308.0
# 30 0 days 00:00:27.760000    239.0    208.0    291.0    198.0
# 31 0 days 00:00:22.109000    292.0    309.0    292.0    324.0
# 32 0 days 00:00:32.469000    257.0    239.0      NaN    302.0
# 33 0 days 00:00:28.785000    225.0    219.0    288.0    222.0
# 34 0 days 00:00:21.659000    291.0    308.0    289.0    322.0
# 35 0 days 00:00:32.524000    199.0    215.0      NaN    303.0
# 36 0 days 00:00:32.746000    226.0    214.0    288.0    167.0
# 37 0 days 00:00:21.709000    294.0    308.0    293.0    325.0
# 38 0 days 00:00:28.472000    246.0    282.0      NaN    304.0
# 39 0 days 00:00:28.320000    225.0    229.0    290.0    192.0
# 40 0 days 00:00:21.699000    293.0    311.0    294.0    327.0
# 41                    NaT    181.0    161.0      NaN    263.0

# %%
fastest_ham = ham_laps.pick_fastest()
tele_ham = fastest_ham.get_telemetry().add_distance()
tele_ham.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      295      8  10547
# 3      296      8  10579
# 4      298      8  10644
# 5      299      8  10707
# 6      301      8  10770
# ..     ...    ...    ...
# 552    294      8  10555
# 553    296      8  10604
# 554    297      8  10620
# 555    298      8  10636
# 556    298      8  10664
#
# [555 rows x 3 columns]

# %%
plt.plot(tele_max.Distance,tele_max.Speed,label = "Verstappen")
plt.plot(tele_nor.Distance,tele_nor.Speed,label = "Norris")
plt.plot(tele_ham.Distance,tele_ham.Speed,label = "Hamilton")
plt.legend()
plt.show()

# %%
def convert_to_normal(time):
    if pd.isna(time):
        return time 
    
    time_str = str(time)  
    parts = time_str.split()
    
    days = int(parts[0])
    minutes, seconds_with_microseconds = parts[2].split(':')[1:]
    seconds, microseconds = seconds_with_microseconds.split('.')
    
    minutes = int(minutes)
    seconds = int(seconds)
    microseconds = int(microseconds)
    
    total_microseconds = days * 86400000000 + minutes * 60000000 + seconds * 1000000 + microseconds
    
    minutes, remaining_microseconds = divmod(total_microseconds, 60000000)
    seconds, microseconds = divmod(remaining_microseconds, 1000000)
    
    normal_time = f"{minutes:02d}:{seconds:02d}.{microseconds:06d}"
    return normal_time

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Vertappen'] * len(max_sec1),
    'Sector1Time': max_sec1,
    'Sector2Time': max_sec2,
    'Sector3Time': max_sec3,
    'Lap Time' : max_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Norris'] * len(nor_sec1),
    'Sector1Time': nor_sec1,
    'Sector2Time': nor_sec2,
    'Sector3Time': nor_sec3,
    'Lap Time' : nor_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Sargeant'] * len(ham_sec1),
    'Sector1Time': ham_sec1,
    'Sector2Time': ham_sec2,
    'Sector3Time': ham_sec3,
    'Lap Time' : ham_lap_time
})



all_drivers_sectors = pd.concat([driver1_sectors, driver2_sectors,driver3_sectors], ignore_index=True)
all_drivers_sectors['Sector1Time'] = all_drivers_sectors['Sector1Time'].apply(convert_to_normal)
all_drivers_sectors['Sector2Time'] = all_drivers_sectors['Sector2Time'].apply(convert_to_normal)
all_drivers_sectors['Sector3Time'] = all_drivers_sectors['Sector3Time'].apply(convert_to_normal)
all_drivers_sectors['Lap Time'] = all_drivers_sectors['Lap Time'].apply(convert_to_normal)
all_drivers_sectors.sort_values(by=["Sector1Time","Sector2Time","Sector3Time"],ascending=True)
# Out:
#        Driver   Sector1Time   Sector2Time   Sector3Time      Lap Time
# 10  Vertappen  00:21.369000  00:28.541000  00:21.493000  01:11.403000
# 22     Norris  00:21.383000  00:28.402000  00:21.598000  01:11.383000
# 16     Norris  00:21.455000  00:28.691000  00:21.726000  01:11.872000
# 34   Sargeant  00:21.456000  00:28.677000  00:21.659000  01:11.792000
# 40   Sargeant  00:21.459000  00:28.543000  00:21.699000  01:11.701000
# 19     Norris  00:21.463000  00:28.592000  00:21.741000  01:11.796000
# 37   Sargeant  00:21.475000  00:28.632000  00:21.709000  01:11.816000
# 28   Sargeant  00:21.516000  00:28.691000  00:21.936000  01:12.143000
# 4   Vertappen  00:21.520000  00:28.553000  00:21.580000  01:11.653000
# 7   Vertappen  00:21.527000  00:28.595000  00:21.551000  01:11.673000
# 31   Sargeant  00:21.544000  00:29.013000  00:22.109000  01:12.666000
# 13     Norris  00:21.579000  00:28.941000  00:21.866000  01:12.386000
# 1   Vertappen  00:21.680000  00:28.887000  00:21.739000  01:12.306000
# 25   Sargeant  00:21.812000  00:29.222000  00:21.999000  01:13.033000
# 32   Sargeant  00:23.890000  00:32.897000  00:32.469000  01:29.256000
# 38   Sargeant  00:24.493000  00:32.203000  00:28.472000  01:25.168000
# 5   Vertappen  00:27.350000  00:36.626000  00:31.651000  01:35.627000
# 20     Norris  00:27.389000  00:36.987000  00:32.184000  01:36.560000
# 35   Sargeant  00:27.609000  00:37.323000  00:32.524000  01:37.456000
# 17     Norris  00:27.774000  00:37.208000  01:05.682000  02:10.664000
# 11  Vertappen  00:27.790000  00:38.104000           NaT           NaT
# 29   Sargeant  00:28.081000  00:40.713000  00:31.328000  01:40.122000
# 41   Sargeant  00:28.689000  00:41.045000           NaT           NaT
# 8   Vertappen  00:28.860000  00:38.176000  00:31.136000  01:38.172000
# 14     Norris  00:29.738000  00:38.386000  00:31.968000  01:40.092000
# 2   Vertappen  00:29.797000  00:42.484000  00:30.528000  01:42.809000
# 23     Norris  00:30.381000  00:39.977000  00:40.837000  01:51.195000
# 26   Sargeant  00:30.820000  00:40.839000  00:34.306000  01:45.965000
# 33   Sargeant  01:39.110000  00:36.447000  00:28.785000           NaT
# 30   Sargeant           NaT  00:34.853000  00:27.760000           NaT
# 24   Sargeant           NaT  00:36.330000  00:30.947000           NaT
# 27   Sargeant           NaT  00:37.153000  00:29.961000           NaT
# 3   Vertappen           NaT  00:37.176000  00:24.866000           NaT
# 12     Norris           NaT  00:37.675000  00:28.327000           NaT
# 36   Sargeant           NaT  00:37.905000  00:32.746000           NaT
# 15     Norris           NaT  00:38.634000  00:29.825000           NaT
# 21     Norris           NaT  00:39.279000  00:31.046000           NaT
# 39   Sargeant           NaT  00:39.435000  00:28.320000           NaT
# 18     Norris           NaT  00:39.494000  00:27.187000           NaT
# 9   Vertappen           NaT  00:40.264000  00:25.316000           NaT
# 6   Vertappen           NaT  00:40.293000  00:25.394000           NaT
# 0   Vertappen           NaT  00:40.931000  00:25.920000           NaT

# %% [markdown]
# **Race**

# %%
race = f1.get_session(2024,"Spain","R")
race.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '44', '63', '16', '55', '81', '11', '10', '31', '27', '14', '24', '18', '3', '77', '20', '23', '22', '2']

# %%
race.results.loc[:,["Abbreviation","TeamName","GridPosition","Position","Time","Status"]]
# Out:
#    Abbreviation         TeamName  GridPosition  Position  \
# 1           VER  Red Bull Racing           2.0       1.0
# 4           NOR          McLaren           1.0       2.0
# 44          HAM         Mercedes           3.0       3.0
# 63          RUS         Mercedes           4.0       4.0
# 16          LEC          Ferrari           5.0       5.0
# 55          SAI          Ferrari           6.0       6.0
# 81          PIA          McLaren           9.0       7.0
# 11          PER  Red Bull Racing          11.0       8.0
# 10          GAS           Alpine           7.0       9.0
# 31          OCO           Alpine           8.0      10.0
# 27          HUL     Haas F1 Team          13.0      11.0
# 14          ALO     Aston Martin          10.0      12.0
# 24          ZHO      Kick Sauber          15.0      13.0
# 18          STR     Aston Martin          14.0      14.0
# 3           RIC               RB          18.0      15.0
# 77          BOT      Kick Sauber          12.0      16.0
# 20          MAG     Haas F1 Team          16.0      17.0
# 23          ALB         Williams           0.0      18.0
# 22          TSU               RB          17.0      19.0
# 2           SAR         Williams          19.0      20.0
#
#                      Time    Status
# 1  0 days 01:28:20.227000  Finished
# 4  0 days 00:00:02.219000  Finished
# 44 0 days 00:00:17.790000  Finished
# 63 0 days 00:00:22.320000  Finished
# 16 0 days 00:00:22.709000  Finished
# 55 0 days 00:00:31.028000  Finished
# 81 0 days 00:00:33.760000  Finished
# 11 0 days 00:00:59.524000  Finished
# 10 0 days 00:01:02.025000  Finished
# 31 0 days 00:01:11.889000  Finished
# 27 0 days 00:01:19.215000  Finished
# 14                    NaT    +1 Lap
# 24                    NaT    +1 Lap
# 18                    NaT    +1 Lap
# 3                     NaT    +1 Lap
# 77                    NaT    +1 Lap
# 20                    NaT    +1 Lap
# 23                    NaT    +1 Lap
# 22                    NaT    +1 Lap
# 2                     NaT   +2 Laps

# %%
race.laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 00:58:20.588000    VER            1 0 days 00:01:23.186000
# 1    0 days 00:59:40.459000    VER            1 0 days 00:01:19.871000
# 2    0 days 01:00:59.823000    VER            1 0 days 00:01:19.364000
# 3    0 days 01:02:20.589000    VER            1 0 days 00:01:20.766000
# 4    0 days 01:03:41.416000    VER            1 0 days 00:01:20.827000
# ...                     ...    ...          ...                    ...
# 1305 0 days 02:19:52.999000    SAR            2 0 days 00:01:24.685000
# 1306 0 days 02:21:14.304000    SAR            2 0 days 00:01:21.305000
# 1307 0 days 02:22:35.680000    SAR            2 0 days 00:01:21.376000
# 1308 0 days 02:23:57.292000    SAR            2 0 days 00:01:21.612000
# 1309 0 days 02:25:22.495000    SAR            2 0 days 00:01:25.203000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0           1.0    1.0        NaT       NaT                    NaT
# 1           2.0    1.0        NaT       NaT 0 days 00:00:24.201000
# 2           3.0    1.0        NaT       NaT 0 days 00:00:23.249000
# 3           4.0    1.0        NaT       NaT 0 days 00:00:24.251000
# 4           5.0    1.0        NaT       NaT 0 days 00:00:24.165000
# ...         ...    ...        ...       ...                    ...
# 1305       60.0    3.0        NaT       NaT 0 days 00:00:24.072000
# 1306       61.0    3.0        NaT       NaT 0 days 00:00:23.892000
# 1307       62.0    3.0        NaT       NaT 0 days 00:00:23.876000
# 1308       63.0    3.0        NaT       NaT 0 days 00:00:23.920000
# 1309       64.0    3.0        NaT       NaT 0 days 00:00:25.139000
#
#                 Sector2Time  ... FreshTyre             Team  \
# 0    0 days 00:00:32.054000  ...     False  Red Bull Racing
# 1    0 days 00:00:31.900000  ...     False  Red Bull Racing
# 2    0 days 00:00:32.086000  ...     False  Red Bull Racing
# 3    0 days 00:00:32.339000  ...     False  Red Bull Racing
# 4    0 days 00:00:32.393000  ...     False  Red Bull Racing
# ...                     ...  ...       ...              ...
# 1305 0 days 00:00:34.369000  ...      True         Williams
# 1306 0 days 00:00:32.790000  ...      True         Williams
# 1307 0 days 00:00:32.868000  ...      True         Williams
# 1308 0 days 00:00:32.884000  ...      True         Williams
# 1309 0 days 00:00:34.847000  ...      True         Williams
#
#                LapStartTime            LapStartDate  TrackStatus  Position  \
# 0    0 days 00:56:57.095000 2024-06-23 13:03:14.413            1       2.0
# 1    0 days 00:58:20.588000 2024-06-23 13:04:37.906            1       2.0
# 2    0 days 00:59:40.459000 2024-06-23 13:05:57.777            1       1.0
# 3    0 days 01:00:59.823000 2024-06-23 13:07:17.141            1       1.0
# 4    0 days 01:02:20.589000 2024-06-23 13:08:37.907            1       1.0
# ...                     ...                     ...          ...       ...
# 1305 0 days 02:18:28.314000 2024-06-23 14:24:45.632            1      20.0
# 1306 0 days 02:19:52.999000 2024-06-23 14:26:10.317            1      20.0
# 1307 0 days 02:21:14.304000 2024-06-23 14:27:31.622            1      20.0
# 1308 0 days 02:22:35.680000 2024-06-23 14:28:52.998            1      20.0
# 1309 0 days 02:23:57.292000 2024-06-23 14:30:14.610            1      20.0
#
#       Deleted  DeletedReason  FastF1Generated IsAccurate
# 0       False                           False      False
# 1       False                           False       True
# 2       False                           False       True
# 3       False                           False       True
# 4       False                           False       True
# ...       ...            ...              ...        ...
# 1305    False                           False       True
# 1306    False                           False       True
# 1307    False                           False       True
# 1308    False                           False       True
# 1309    False                           False       True
#
# [1310 rows x 31 columns]

# %%
max_race = race.laps.pick_driver("VER")
fastest_lap_max_race = max_race.pick_fastest().LapTime
max_race_lap_time = max_race["LapTime"]
max_race_sec1 = max_race["Sector1Time"]
max_race_sec2 = max_race["Sector2Time"]
max_race_sec3 = max_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_max_race),"which was in Lap number",max_race.pick_fastest().LapNumber)
max_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:17.776000 which was in Lap number 54.0
#                   LapTime            Sector1Time            Sector2Time  \
# 0  0 days 00:01:23.186000                    NaT 0 days 00:00:32.054000
# 1  0 days 00:01:19.871000 0 days 00:00:24.201000 0 days 00:00:31.900000
# 2  0 days 00:01:19.364000 0 days 00:00:23.249000 0 days 00:00:32.086000
# 3  0 days 00:01:20.766000 0 days 00:00:24.251000 0 days 00:00:32.339000
# 4  0 days 00:01:20.827000 0 days 00:00:24.165000 0 days 00:00:32.393000
# ..                    ...                    ...                    ...
# 61 0 days 00:01:18.301000 0 days 00:00:23.228000 0 days 00:00:31.628000
# 62 0 days 00:01:18.543000 0 days 00:00:23.252000 0 days 00:00:31.685000
# 63 0 days 00:01:19.072000 0 days 00:00:23.303000 0 days 00:00:31.953000
# 64 0 days 00:01:19.467000 0 days 00:00:23.258000 0 days 00:00:32.109000
# 65 0 days 00:01:19.774000 0 days 00:00:23.251000 0 days 00:00:32.326000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 0  0 days 00:00:23.658000    262.0    270.0    276.0    270.0
# 1  0 days 00:00:23.770000      NaN    276.0    280.0    300.0
# 2  0 days 00:00:24.029000    266.0    269.0    273.0    324.0
# 3  0 days 00:00:24.176000    261.0    265.0    273.0    292.0
# 4  0 days 00:00:24.269000    260.0    262.0    272.0    296.0
# ..                    ...      ...      ...      ...      ...
# 61 0 days 00:00:23.445000    279.0    278.0    283.0      NaN
# 62 0 days 00:00:23.606000    278.0    283.0    283.0    306.0
# 63 0 days 00:00:23.816000    273.0    279.0    285.0      NaN
# 64 0 days 00:00:24.100000      NaN    277.0    287.0    308.0
# 65 0 days 00:00:24.197000    274.0    265.0    280.0    324.0
#
# [66 rows x 8 columns]

# %%
fastest_lap_race_max = max_race.pick_fastest()
tele_race_max= fastest_lap_race_max.get_telemetry().add_distance()
speed_race_max = tele_race_max.Speed
tele_race_max.loc[:,["Speed","nGear","RPM"]]
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#      Speed  nGear    RPM
# 2      284      7  11288
# 3      285      7  11316
# 4      285      7  11314
# 5      286      7  11313
# 6      287      7  11312
# ..     ...    ...    ...
# 598    282      7  11245
# 599    282      7  11262
# 600    283      7  11280
# 601    284      7  11301
# 602    285      7  11311
#
# [601 rows x 3 columns]

# %%
nor_race = race.laps.pick_driver("NOR")
fastest_lap_nor_race = nor_race.pick_fastest().LapTime
nor_race_lap_time = nor_race["LapTime"]
nor_race_sec1 = nor_race["Sector1Time"]
nor_race_sec2 = nor_race["Sector2Time"]
nor_race_sec3 = nor_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_nor_race),"which was in Lap number",nor_race.pick_fastest().LapNumber)
nor_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:17.115000 which was in Lap number 51.0
#                    LapTime            Sector1Time            Sector2Time  \
# 66  0 days 00:01:23.953000                    NaT 0 days 00:00:32.415000
# 67  0 days 00:01:20.215000 0 days 00:00:24.310000 0 days 00:00:32.014000
# 68  0 days 00:01:20.243000 0 days 00:00:23.900000 0 days 00:00:32.182000
# 69  0 days 00:01:20.702000 0 days 00:00:24.100000 0 days 00:00:32.487000
# 70  0 days 00:01:21.134000 0 days 00:00:24.079000 0 days 00:00:32.638000
# ..                     ...                    ...                    ...
# 127 0 days 00:01:18.080000 0 days 00:00:23.013000 0 days 00:00:31.558000
# 128 0 days 00:01:18.174000 0 days 00:00:22.953000 0 days 00:00:31.706000
# 129 0 days 00:01:18.282000 0 days 00:00:22.868000 0 days 00:00:31.704000
# 130 0 days 00:01:18.773000 0 days 00:00:22.909000 0 days 00:00:31.991000
# 131 0 days 00:01:19.682000 0 days 00:00:23.436000 0 days 00:00:32.053000
#
#                Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 66  0 days 00:00:23.736000    254.0    260.0    275.0    270.0
# 67  0 days 00:00:23.891000    261.0    264.0    276.0    299.0
# 68  0 days 00:00:24.161000    254.0    267.0    277.0    321.0
# 69  0 days 00:00:24.115000    250.0    268.0    279.0    318.0
# 70  0 days 00:00:24.417000    249.0    259.0    278.0    324.0
# ..                     ...      ...      ...      ...      ...
# 127 0 days 00:00:23.509000    273.0    280.0    284.0    307.0
# 128 0 days 00:00:23.515000    272.0    280.0    285.0    309.0
# 129 0 days 00:00:23.710000    275.0    283.0    285.0    308.0
# 130 0 days 00:00:23.873000    277.0    285.0    283.0    309.0
# 131 0 days 00:00:24.193000    271.0    281.0    273.0    310.0
#
# [66 rows x 8 columns]

# %%
fastest_lap_race_nor = nor_race.pick_fastest()
tele_race_nor= fastest_lap_race_nor.get_telemetry().add_distance()
speed_race_nor = tele_race_nor.Speed
tele_race_nor.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      288      7  11572
# 3      289      7  11593
# 4      291      7  11635
# 5      292      7  11178
# 6      294      7  10722
# ..     ...    ...    ...
# 588    282      7  11295
# 589    282      7  11362
# 590    283      7  11429
# 591    284      7  11425
# 592    284      7  11423
#
# [591 rows x 3 columns]

# %%
ham_race = race.laps.pick_driver("HAM")
fastest_lap_ham_race = ham_race.pick_fastest().LapTime
ham_race_lap_time = ham_race["LapTime"]
ham_race_sec1 = ham_race["Sector1Time"]
ham_race_sec2 = ham_race["Sector2Time"]
ham_race_sec3 = ham_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_ham_race),"which was in Lap number",ham_race.pick_fastest().LapNumber)
ham_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:17.809000 which was in Lap number 46.0
#                    LapTime            Sector1Time            Sector2Time  \
# 132 0 days 00:01:24.441000                    NaT 0 days 00:00:32.524000
# 133 0 days 00:01:20.594000 0 days 00:00:24.248000 0 days 00:00:32.276000
# 134 0 days 00:01:20.421000 0 days 00:00:23.619000 0 days 00:00:32.545000
# 135 0 days 00:01:20.496000 0 days 00:00:23.788000 0 days 00:00:32.624000
# 136 0 days 00:01:21.050000 0 days 00:00:23.672000 0 days 00:00:32.908000
# ..                     ...                    ...                    ...
# 193 0 days 00:01:19.337000 0 days 00:00:23.200000 0 days 00:00:32.076000
# 194 0 days 00:01:18.942000 0 days 00:00:22.904000 0 days 00:00:32.051000
# 195 0 days 00:01:19.166000 0 days 00:00:23.192000 0 days 00:00:32.085000
# 196 0 days 00:01:19.009000 0 days 00:00:23.215000 0 days 00:00:31.893000
# 197 0 days 00:01:20.041000 0 days 00:00:23.347000 0 days 00:00:32.280000
#
#                Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 132 0 days 00:00:23.875000    251.0    259.0    277.0    282.0
# 133 0 days 00:00:24.070000    256.0    266.0    279.0    296.0
# 134 0 days 00:00:24.257000    259.0    264.0    277.0    328.0
# 135 0 days 00:00:24.084000      NaN    268.0    279.0    324.0
# 136 0 days 00:00:24.470000    255.0    263.0    279.0    329.0
# ..                     ...      ...      ...      ...      ...
# 193 0 days 00:00:24.061000    283.0    283.0    286.0    312.0
# 194 0 days 00:00:23.987000    278.0    284.0    281.0    333.0
# 195 0 days 00:00:23.889000    282.0    282.0    283.0    309.0
# 196 0 days 00:00:23.901000    287.0    280.0    283.0      NaN
# 197 0 days 00:00:24.414000    286.0    265.0    278.0      NaN
#
# [66 rows x 8 columns]

# %%
fastest_lap_race_ham = ham_race.pick_fastest()
tele_race_ham= fastest_lap_race_ham.get_telemetry().add_distance()
speed_race_ham = tele_race_ham.Speed
tele_race_ham.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      294      8  10535
# 3      295      8  10576
# 4      298      8  10659
# 5      299      8  10731
# 6      301      8  10804
# ..     ...    ...    ...
# 592    282      7  11671
# 593    284      7  11711
# 594    286      7  11752
# 595    288      7  11793
# 596    289      7  11878
#
# [595 rows x 3 columns]

# %%
plt.plot(tele_race_max.Distance,speed_race_max,label = "Verstappen")
plt.plot(tele_race_nor.Distance,speed_race_nor,label="Norris")
plt.plot(tele_race_ham.Distance,speed_race_ham,label = "Hamilton")
plt.legend()
plt.show()

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Norris'] * len(nor_race_sec1),
    'Sector1Time': nor_race_sec1,
    'Sector2Time': nor_race_sec2,
    'Sector3Time': nor_race_sec3,
    'Lap Time' : nor_race_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Verstappen'] * len(max_race_sec1),
    'Sector1Time': max_race_sec1,
    'Sector2Time': max_race_sec2,
    'Sector3Time': max_race_sec3,
    'Lap Time' : max_race_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Hamilton'] * len(ham_race_sec1),
    'Sector1Time': ham_race_sec1,
    'Sector2Time': ham_race_sec2,
    'Sector3Time': ham_race_sec3,
    'Lap Time' : ham_race_lap_time
})


all_drivers_sectors = pd.concat([driver1_sectors, driver2_sectors, driver3_sectors], ignore_index=True)
all_drivers_sectors['Sector1Time'] = all_drivers_sectors['Sector1Time'].apply(convert_to_normal)
all_drivers_sectors['Sector2Time'] = all_drivers_sectors['Sector2Time'].apply(convert_to_normal)
all_drivers_sectors['Sector3Time'] = all_drivers_sectors['Sector3Time'].apply(convert_to_normal)
all_drivers_sectors['Lap Time'] = all_drivers_sectors['Lap Time'].apply(convert_to_normal)
all_drivers_sectors.sort_values(by=["Sector1Time","Sector2Time","Sector3Time"],ascending=True)
# Out:
#          Driver   Sector1Time   Sector2Time   Sector3Time      Lap Time
# 177    Hamilton  00:22.564000  00:31.355000  00:23.890000  01:17.809000
# 60       Norris  00:22.595000  00:31.667000  00:23.543000  01:17.805000
# 55       Norris  00:22.602000  00:31.610000  00:23.415000  01:17.627000
# 48       Norris  00:22.611000  00:31.288000  00:23.478000  01:17.377000
# 50       Norris  00:22.626000  00:31.243000  00:23.246000  01:17.115000
# ..          ...           ...           ...           ...           ...
# 47       Norris  00:42.327000  00:31.348000  00:23.451000  01:37.126000
# 110  Verstappen  00:42.408000  00:31.274000  00:23.371000  01:37.053000
# 66   Verstappen           NaT  00:32.054000  00:23.658000  01:23.186000
# 0        Norris           NaT  00:32.415000  00:23.736000  01:23.953000
# 132    Hamilton           NaT  00:32.524000  00:23.875000  01:24.441000
#
# [198 rows x 5 columns]

# %%
res = race.results
drivers = res['Abbreviation'].tolist()
fastest_speed = pd.DataFrame(columns=['Driver', 'Speed'])
for i in drivers:
    tele = race.laps.pick_driver(i)
    speed = tele.SpeedST.max()
    df = pd.DataFrame({'Driver': [i], 'Speed': [speed]})
    fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
fastest_speed.sort_values(by="Speed",ascending=True)
# Out:
# /tmp/ipykernel_31064/2770152713.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
#    Driver  Speed
# 0     VER  324.0
# 9     OCO  326.0
# 3     RUS  329.0
# 8     GAS  329.0
# 19    SAR  330.0
# 6     PIA  331.0
# 18    TSU  332.0
# 1     NOR  332.0
# 11    ALO  332.0
# 15    BOT  333.0
# 7     PER  333.0
# 13    STR  334.0
# 10    HUL  334.0
# 5     SAI  334.0
# 14    RIC  336.0
# 4     LEC  336.0
# 12    ZHO  337.0
# 2     HAM  338.0
# 17    ALB  339.0
# 16    MAG  343.0

# %%
fig,ax = plt.subplots(figsize=(18, 6))


bars = ax.bar(fastest_speed['Driver'], fastest_speed['Speed'])

ax.set_xlabel('Drivers')

ax.set_ylabel('Speed')

ax.set_title('Maximum Speeds of Drivers')

plt.xticks(rotation=45, ha='right')

y_min = 275
y_max = np.ceil(fastest_speed['Speed'].max() / 5) * 5 + 5
y_ticks = np.arange(y_min, y_max, 5)
ax.set_ylim(y_min, y_max)
ax.set_yticks(y_ticks)

for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.2f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

# Display the plot
plt.show()
