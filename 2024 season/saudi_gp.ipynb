# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fastf1 as f1

# %%
f1.Cache.enable_cache('../cache')

# %% [markdown]
# # Saudi Arabia Grand Prix 2024

# %% [markdown]
# **Qualifying**

# %%
quali = f1.get_session(2024,"Saudi Arabia","Qualifying")
quali.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.3.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# ...

# %%
quali.session_info
# Out:
# {'Meeting': {'Key': 1230,
#   'Name': 'Saudi Arabian Grand Prix',
#   'OfficialName': 'FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2024',
#   'Location': 'Jeddah',
#   'Country': {'Key': 153, 'Code': 'KSA', 'Name': 'Saudi Arabia'},
#   'Circuit': {'Key': 149, 'ShortName': 'Jeddah'}},
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 9476,
#  'Type': 'Qualifying',
#  'Name': 'Qualifying',
#  'StartDate': datetime.datetime(2024, 3, 8, 20, 0),
#  'EndDate': datetime.datetime(2024, 3, 8, 21, 0),
#  'GmtOffset': datetime.timedelta(seconds=10800),
#  'Path': '2024/2024-03-09_Saudi_Arabian_Grand_Prix/2024-03-08_Qualifying/'}

# %%
quali.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 4             4      L NORRIS          NOR           norris          McLaren
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# 18           18      L STROLL          STR           stroll     Aston Martin
# 38           38     O BEARMAN          BEA          bearman          Ferrari
# ...

# %%
bearman = quali.get_driver("BEA")
bearman
# Out:
# DriverNumber                              38
# BroadcastName                      O BEARMAN
# Abbreviation                             BEA
# DriverId                             bearman
# TeamName                             Ferrari
# TeamColor                             e8002d
# TeamId                               ferrari
# FirstName                             Oliver
# LastName                             Bearman
# FullName                      Oliver Bearman
# HeadshotUrl                             None
# CountryCode                              GBR
# Position                                11.0
# ClassifiedPosition
# GridPosition                             NaN
# Q1                    0 days 00:01:28.984000
# Q2                    0 days 00:01:28.642000
# Q3                                       NaT
# Time                                     NaT
# Status
# Points                                   NaN
# Name: 38, dtype: object

# %%
bearman_laps = quali.laps.pick_driver("BEA")
bea_lap_time = bearman_laps["LapTime"]
bea_sec1 = bearman_laps["Sector1Time"]
bea_sec2 = bearman_laps["Sector2Time"]
bea_sec3 = bearman_laps["Sector3Time"]
bearman_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                    LapTime            Sector1Time            Sector2Time  \
# 204                    NaT                    NaT 0 days 00:00:32.821000
# 205 0 days 00:01:30.136000 0 days 00:00:33.008000 0 days 00:00:28.529000
# 206 0 days 00:01:55.341000 0 days 00:00:46.665000 0 days 00:00:34.654000
# 207 0 days 00:01:28.984000 0 days 00:00:32.439000 0 days 00:00:28.268000
# 208 0 days 00:01:58.354000 0 days 00:00:44.909000 0 days 00:00:37.989000
# 209 0 days 00:01:29.160000 0 days 00:00:32.449000 0 days 00:00:28.286000
# 210 0 days 00:01:53.108000 0 days 00:00:41.268000 0 days 00:00:32.340000
# 211                    NaT                    NaT 0 days 00:00:32.652000
# 212 0 days 00:01:55.625000 0 days 00:00:37.742000 0 days 00:00:35.286000
# 213                    NaT                    NaT 0 days 00:00:32.713000
# 214                    NaT 0 days 00:00:32.307000 0 days 00:00:28.147000
# 215                    NaT                    NaT 0 days 00:00:32.485000
# ...

# %%
fastest_bearman = quali.laps.pick_driver("BEA").pick_fastest()
tele_bearman = fastest_bearman.get_telemetry().add_distance()
tele_bearman.loc[:,["Speed","nGear","RPM"]]
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#      Speed  nGear    RPM
# 2      307      8  10934
# 3      308      8  10951
# 4      309      8  10985
# 5      310      8  11019
# 6      311      8  11057
# ..     ...    ...    ...
# 686    303      8  10717
# 687    303      8  10809
# 688    304      8  10836
# 689    305      8  10863
# 690    305      8  10876
#
# [689 rows x 3 columns]

# %%
alonso_laps = quali.laps.pick_driver("ALO")
alonso_lap_time = alonso_laps["LapTime"]
alo_sec1 = alonso_laps["Sector1Time"]
alo_sec2 = alonso_laps["Sector2Time"]
alo_sec3 = alonso_laps["Sector3Time"]
alonso_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 60                    NaT                    NaT 0 days 00:00:30.753000
# 61 0 days 00:01:28.876000 0 days 00:00:32.358000 0 days 00:00:28.062000
# 62 0 days 00:01:55.058000 0 days 00:00:46.428000 0 days 00:00:34.749000
# 63 0 days 00:01:49.102000 0 days 00:00:39.916000 0 days 00:00:34.684000
# 64 0 days 00:01:28.706000 0 days 00:00:32.092000 0 days 00:00:27.984000
# 65 0 days 00:01:56.114000 0 days 00:00:40.459000 0 days 00:00:33.183000
# 66                    NaT                    NaT 0 days 00:00:31.711000
# 67 0 days 00:01:59.835000 0 days 00:00:35.988000 0 days 00:00:41.482000
# 68                    NaT                    NaT 0 days 00:00:30.001000
# 69 0 days 00:01:28.122000 0 days 00:00:31.964000 0 days 00:00:27.859000
# 70 0 days 00:01:54.230000 0 days 00:00:43.708000 0 days 00:00:34.638000
# 71                    NaT                    NaT 0 days 00:00:30.514000
# ...

# %%
fastest_alonso = alonso_laps.pick_fastest()
tele_alonso = fastest_alonso.get_telemetry().add_distance()
tele_alonso.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      317      8  11353
# 3      318      8  11369
# 4      319      8  11401
# 5      320      8  11402
# 6      321      8  11403
# ..     ...    ...    ...
# 667    304      8  10911
# 668    305      8  10934
# 669    306      8  10959
# 670    308      8  10985
# 671    309      8  10997
#
# [670 rows x 3 columns]

# %%
leclerc_laps = quali.laps.pick_driver("BEA")
lec_lap_time = leclerc_laps["LapTime"]
lec_sec1 = leclerc_laps["Sector1Time"]
lec_sec2 = leclerc_laps["Sector2Time"]
lec_sec3 = leclerc_laps["Sector3Time"]
leclerc_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                    LapTime            Sector1Time            Sector2Time  \
# 204                    NaT                    NaT 0 days 00:00:32.821000
# 205 0 days 00:01:30.136000 0 days 00:00:33.008000 0 days 00:00:28.529000
# 206 0 days 00:01:55.341000 0 days 00:00:46.665000 0 days 00:00:34.654000
# 207 0 days 00:01:28.984000 0 days 00:00:32.439000 0 days 00:00:28.268000
# 208 0 days 00:01:58.354000 0 days 00:00:44.909000 0 days 00:00:37.989000
# 209 0 days 00:01:29.160000 0 days 00:00:32.449000 0 days 00:00:28.286000
# 210 0 days 00:01:53.108000 0 days 00:00:41.268000 0 days 00:00:32.340000
# 211                    NaT                    NaT 0 days 00:00:32.652000
# 212 0 days 00:01:55.625000 0 days 00:00:37.742000 0 days 00:00:35.286000
# 213                    NaT                    NaT 0 days 00:00:32.713000
# 214                    NaT 0 days 00:00:32.307000 0 days 00:00:28.147000
# 215                    NaT                    NaT 0 days 00:00:32.485000
# ...

# %%
fastest_lec = leclerc_laps.pick_fastest()
tele_lec = fastest_lec.get_telemetry().add_distance()
tele_lec.loc[:,["Speed","nGear","RPM"]]
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#      Speed  nGear    RPM
# 2      307      8  10934
# 3      308      8  10951
# 4      309      8  10985
# 5      310      8  11019
# 6      311      8  11057
# ..     ...    ...    ...
# 686    303      8  10717
# 687    303      8  10809
# 688    304      8  10836
# 689    305      8  10863
# 690    305      8  10876
#
# [689 rows x 3 columns]

# %%
plt.plot(tele_bearman.Distance,tele_bearman.Speed,label="Bearman")
plt.plot(tele_alonso.Distance,tele_alonso.Speed,label = "Alonso")
plt.plot(tele_lec.Distance,tele_lec.Speed,label = "Leclerc")
plt.legend()
plt.show()

# %%
def convert_to_normal(time):
    if pd.isna(time):
        return time 
    
    time_str = str(time)  
    parts = time_str.split()
    
    days = int(parts[0])
    minutes, seconds_with_microseconds = parts[2].split(':')[1:]
    seconds, microseconds = seconds_with_microseconds.split('.')
    
    minutes = int(minutes)
    seconds = int(seconds)
    microseconds = int(microseconds)
    
    total_microseconds = days * 86400000000 + minutes * 60000000 + seconds * 1000000 + microseconds
    
    minutes, remaining_microseconds = divmod(total_microseconds, 60000000)
    seconds, microseconds = divmod(remaining_microseconds, 1000000)
    
    normal_time = f"{minutes:02d}:{seconds:02d}.{microseconds:06d}"
    return normal_time

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Leclerc'] * len(lec_sec1),
    'Sector1Time': lec_sec1,
    'Sector2Time': lec_sec2,
    'Sector3Time': lec_sec3,
    'Lap Time' : lec_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Alonso'] * len(alo_sec1),
    'Sector1Time': alo_sec1,
    'Sector2Time': alo_sec2,
    'Sector3Time': alo_sec3,
    'Lap Time' : alonso_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Bearman'] * len(bea_sec1),
    'Sector1Time': bea_sec1,
    'Sector2Time': bea_sec2,
    'Sector3Time': bea_sec3,
    'Lap Time' : bea_lap_time
})

all_drivers_sectors = pd.concat([driver1_sectors, driver2_sectors, driver3_sectors], ignore_index=True)
all_drivers_sectors['Sector1Time'] = all_drivers_sectors['Sector1Time'].apply(convert_to_normal)
all_drivers_sectors['Sector2Time'] = all_drivers_sectors['Sector2Time'].apply(convert_to_normal)
all_drivers_sectors['Sector3Time'] = all_drivers_sectors['Sector3Time'].apply(convert_to_normal)
all_drivers_sectors['Lap Time'] = all_drivers_sectors['Lap Time'].apply(convert_to_normal)
all_drivers_sectors.sort_values(by=["Sector1Time","Sector2Time","Sector3Time"],ascending=True)
# Out:
#      Driver   Sector1Time   Sector2Time   Sector3Time      Lap Time
# 33   Alonso  00:31.840000  00:27.823000  00:28.183000  01:27.846000
# 30   Alonso  00:31.908000  00:27.842000  00:28.238000  01:27.988000
# 27   Alonso  00:31.964000  00:27.859000  00:28.299000  01:28.122000
# 22   Alonso  00:32.092000  00:27.984000  00:28.630000  01:28.706000
# 16  Leclerc  00:32.255000  00:28.115000  00:28.272000  01:28.642000
# 51  Bearman  00:32.255000  00:28.115000  00:28.272000  01:28.642000
# 10  Leclerc  00:32.307000  00:28.147000           NaT           NaT
# 45  Bearman  00:32.307000  00:28.147000           NaT           NaT
# 19   Alonso  00:32.358000  00:28.062000  00:28.456000  01:28.876000
# 14  Leclerc  00:32.361000  00:28.061000  00:28.493000  01:28.915000
# 49  Bearman  00:32.361000  00:28.061000  00:28.493000  01:28.915000
# 3   Leclerc  00:32.439000  00:28.268000  00:28.277000  01:28.984000
# 38  Bearman  00:32.439000  00:28.268000  00:28.277000  01:28.984000
# ...

# %% [markdown]
# **Race**

# %%
race = f1.get_session(2024,"Saudi Arabia","R")
race.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.3.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 38: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# ...

# %%
race.results.loc[:,["Abbreviation","TeamName","GridPosition","Position","Time","Status"]]
# Out:
#    Abbreviation         TeamName  GridPosition  Position  \
# 1           VER  Red Bull Racing           1.0       1.0
# 11          PER  Red Bull Racing           3.0       2.0
# 16          LEC          Ferrari           2.0       3.0
# 81          PIA          McLaren           5.0       4.0
# 14          ALO     Aston Martin           4.0       5.0
# 63          RUS         Mercedes           7.0       6.0
# 38          BEA          Ferrari          11.0       7.0
# 4           NOR          McLaren           6.0       8.0
# 44          HAM         Mercedes           8.0       9.0
# 27          HUL     Haas F1 Team          15.0      10.0
# 23          ALB         Williams          12.0      11.0
# 20          MAG     Haas F1 Team          13.0      12.0
# 31          OCO           Alpine          17.0      13.0
# 22          TSU               RB           9.0      14.0
# 2           SAR         Williams          19.0      15.0
# ...

# %%
ver_race = race.laps.pick_driver("VER")
fastest_lap_max_race = ver_race.pick_fastest().LapTime
print("Fastest Lap:",fastest_lap_max_race,"which was in Lap number",ver_race.pick_fastest().LapNumber)
time_columns = ["LapTime", "Sector1Time", "Sector2Time", "Sector3Time"]
ver_race.loc[:, time_columns] = ver_race.loc[:, time_columns].apply(pd.to_timedelta)
ver_race.loc[:,["LapNumber","LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2"]]
# Out:
# Fastest Lap: 0 days 00:01:31.773000 which was in Lap number 50.0
#     LapNumber                LapTime            Sector1Time  \
# 0         1.0 0 days 00:01:35.505000                    NaT
# 1         2.0 0 days 00:01:34.205000 0 days 00:00:34.720000
# 2         3.0 0 days 00:01:34.043000 0 days 00:00:34.530000
# 3         4.0 0 days 00:01:33.754000 0 days 00:00:34.416000
# 4         5.0 0 days 00:01:33.955000 0 days 00:00:34.457000
# 5         6.0 0 days 00:01:33.676000 0 days 00:00:34.355000
# 6         7.0 0 days 00:02:02.919000 0 days 00:00:34.467000
# 7         8.0                    NaT 0 days 00:01:13.947000
# 8         9.0                    NaT 0 days 00:00:56.642000
# 9        10.0 0 days 00:01:35.024000 0 days 00:00:35.648000
# 10       11.0 0 days 00:01:33.610000 0 days 00:00:34.555000
# 11       12.0 0 days 00:01:33.321000 0 days 00:00:34.391000
# 12       13.0 0 days 00:01:33.144000 0 days 00:00:34.096000
# 13       14.0 0 days 00:01:33.194000 0 days 00:00:34.303000
# ...

# %%
fastest_lap_race_max = race.laps.pick_driver("VER").pick_fastest()
tele_race_max= fastest_lap_race_max.get_telemetry().add_distance()
speed_race_max = tele_race_max.Speed
tele_race_max
# Out:
#                        Date            SessionTime DriverAhead  \
# 2   2024-03-09 18:23:10.870 0 days 02:18:55.650000
# 3   2024-03-09 18:23:10.991 0 days 02:18:55.771000
# 4   2024-03-09 18:23:10.994 0 days 02:18:55.774000
# 5   2024-03-09 18:23:11.354 0 days 02:18:56.134000
# 6   2024-03-09 18:23:11.391 0 days 02:18:56.171000
# ..                      ...                    ...         ...
# 718 2024-03-09 18:24:42.251 0 days 02:20:27.031000
# 719 2024-03-09 18:24:42.355 0 days 02:20:27.135000
# 720 2024-03-09 18:24:42.431 0 days 02:20:27.211000
# 721 2024-03-09 18:24:42.515 0 days 02:20:27.295000
# 722 2024-03-09 18:24:42.643 0 days 02:20:27.423000
#
#      DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                      NaN        0 days 00:00:00  10638    297      8
# 3                      NaN 0 days 00:00:00.121000  10648    298      8
# 4                      NaN 0 days 00:00:00.124000  10667    300      8
# ...

# %%
bea_race = race.laps.pick_driver("BEA")
fastest_lap_max_race = bea_race.pick_fastest().LapTime
print("Fastest Lap:",fastest_lap_max_race,"which was in Lap number",ver_race.pick_fastest().LapNumber)
time_columns = ["LapTime", "Sector1Time", "Sector2Time", "Sector3Time"]
bea_race.loc[:, time_columns] = bea_race.loc[:, time_columns].apply(pd.to_timedelta)
bea_race.loc[:,["LapNumber","LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2"]]
# Out:
# Fastest Lap: 0 days 00:01:32.186000 which was in Lap number 50.0
#      LapNumber                LapTime            Sector1Time  \
# 602        1.0 0 days 00:01:42.621000                    NaT
# 603        2.0 0 days 00:01:37.415000 0 days 00:00:37.634000
# 604        3.0 0 days 00:01:35.515000 0 days 00:00:35.728000
# 605        4.0 0 days 00:01:35.645000 0 days 00:00:35.862000
# 606        5.0 0 days 00:01:35.593000 0 days 00:00:35.766000
# 607        6.0 0 days 00:01:36.122000 0 days 00:00:35.873000
# 608        7.0 0 days 00:02:11.168000 0 days 00:00:41.828000
# 609        8.0                    NaT 0 days 00:01:06.315000
# 610        9.0 0 days 00:02:27.117000 0 days 00:00:52.761000
# 611       10.0 0 days 00:01:38.427000 0 days 00:00:37.734000
# 612       11.0 0 days 00:01:35.645000 0 days 00:00:35.816000
# 613       12.0 0 days 00:01:34.907000 0 days 00:00:35.377000
# 614       13.0 0 days 00:01:35.153000 0 days 00:00:35.641000
# ...
