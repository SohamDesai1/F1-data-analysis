# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fastf1 as f1
from ing_theme_matplotlib import mpl_style
import mplcyberpunk

# %%
f1.Cache.enable_cache('../cache')

# %%
quali = f1.get_session(2024,"Belgium","Qualifying")
quali.load()
# Out:
# core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '11', '44', '4', '81', '63', '55', '14', '31', '23', '10', '3', '77', '18', '27', '20', '22', '2', '24']

# %%
quali.session_info
# Out:
# {'Meeting': {'Key': 1242,
#   'Name': 'Belgian Grand Prix',
#   'OfficialName': 'FORMULA 1 ROLEX BELGIAN GRAND PRIX 2024',
#   'Location': 'Spa-Francorchamps',
#   'Country': {'Key': 16, 'Code': 'BEL', 'Name': 'Belgium'},
#   'Circuit': {'Key': 7, 'ShortName': 'Spa-Francorchamps'}},
#  'ArchiveStatus': {'Status': 'Generating'},
#  'Key': 9570,
#  'Type': 'Qualifying',
#  'Name': 'Qualifying',
#  'StartDate': datetime.datetime(2024, 7, 27, 16, 0),
#  'EndDate': datetime.datetime(2024, 7, 27, 17, 0),
#  'GmtOffset': datetime.timedelta(seconds=7200),
#  'Path': '2024/2024-07-28_Belgian_Grand_Prix/2024-07-27_Qualifying/'}

# %%
quali.results.loc[:,["Abbreviation","TeamName","GridPosition","Position","Time","Status"]]
# Out:
#    Abbreviation         TeamName  GridPosition  Position Time Status
# 1           VER  Red Bull Racing           NaN       1.0  NaT
# 16          LEC          Ferrari           NaN       2.0  NaT
# 11          PER  Red Bull Racing           NaN       3.0  NaT
# 44          HAM         Mercedes           NaN       4.0  NaT
# 4           NOR          McLaren           NaN       5.0  NaT
# 81          PIA          McLaren           NaN       6.0  NaT
# 63          RUS         Mercedes           NaN       7.0  NaT
# 55          SAI          Ferrari           NaN       8.0  NaT
# 14          ALO     Aston Martin           NaN       9.0  NaT
# 31          OCO           Alpine           NaN      10.0  NaT
# 23          ALB         Williams           NaN      11.0  NaT
# 10          GAS           Alpine           NaN      12.0  NaT
# 3           RIC               RB           NaN      13.0  NaT
# 77          BOT      Kick Sauber           NaN      14.0  NaT
# 18          STR     Aston Martin           NaN      15.0  NaT
# 27          HUL     Haas F1 Team           NaN      16.0  NaT
# 20          MAG     Haas F1 Team           NaN      17.0  NaT
# 22          TSU               RB           NaN      18.0  NaT
# 2           SAR         Williams           NaN      19.0  NaT
# 24          ZHO      Kick Sauber           NaN      20.0  NaT

# %%
quali.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:18:39.870000    VER            1                    NaT
# 1   0 days 00:20:35.873000    VER            1 0 days 00:01:56.003000
# 2   0 days 00:23:25.069000    VER            1                    NaT
# 3   0 days 00:25:48.495000    VER            1 0 days 00:02:23.426000
# 4   0 days 00:27:43.433000    VER            1 0 days 00:01:54.938000
# ..                     ...    ...          ...                    ...
# 343 0 days 00:25:39.343000    ZHO           24 0 days 00:01:57.775000
# 344 0 days 00:27:51.298000    ZHO           24 0 days 00:02:11.955000
# 345 0 days 00:32:22.882000    ZHO           24                    NaT
# 346 0 days 00:34:23.384000    ZHO           24 0 days 00:02:00.502000
# 347 0 days 00:36:44.927000    ZHO           24 0 days 00:02:21.543000
#
#      LapNumber  Stint             PitOutTime              PitInTime  \
# 0          1.0    1.0 0 days 00:16:36.796000                    NaT
# 1          2.0    1.0                    NaT                    NaT
# 2          3.0    1.0                    NaT                    NaT
# 3          4.0    1.0                    NaT                    NaT
# 4          5.0    1.0                    NaT                    NaT
# ..         ...    ...                    ...                    ...
# 343        5.0    1.0                    NaT                    NaT
# 344        6.0    1.0                    NaT 0 days 00:27:47.446000
# 345        7.0    2.0 0 days 00:29:49.718000                    NaT
# 346        8.0    2.0                    NaT                    NaT
# 347        9.0    2.0                    NaT 0 days 00:36:40.999000
#
#                Sector1Time            Sector2Time  ... FreshTyre  \
# 0                      NaT 0 days 00:00:56.729000  ...      True
# 1   0 days 00:00:32.405000 0 days 00:00:53.127000  ...      True
# 2   0 days 00:00:48.404000 0 days 00:01:18.497000  ...      True
# 3   0 days 00:00:34.776000 0 days 00:01:11.608000  ...      True
# 4   0 days 00:00:32.217000 0 days 00:00:52.289000  ...      True
# ..                     ...                    ...  ...       ...
# 343 0 days 00:00:32.484000 0 days 00:00:54.494000  ...      True
# 344 0 days 00:00:34.821000 0 days 00:00:57.230000  ...      True
# 345                    NaT 0 days 00:00:59.301000  ...      True
# 346 0 days 00:00:34.573000 0 days 00:00:55.031000  ...      True
# 347 0 days 00:00:39.069000 0 days 00:01:00.470000  ...      True
#
#                 Team           LapStartTime            LapStartDate  \
# 0    Red Bull Racing 0 days 00:16:36.796000 2024-07-27 14:02:07.246
# 1    Red Bull Racing 0 days 00:18:39.870000 2024-07-27 14:04:10.320
# 2    Red Bull Racing 0 days 00:20:35.873000 2024-07-27 14:06:06.323
# 3    Red Bull Racing 0 days 00:23:25.069000 2024-07-27 14:08:55.519
# 4    Red Bull Racing 0 days 00:25:48.495000 2024-07-27 14:11:18.945
# ..               ...                    ...                     ...
# 343      Kick Sauber 0 days 00:23:41.568000 2024-07-27 14:09:12.018
# 344      Kick Sauber 0 days 00:25:39.343000 2024-07-27 14:11:09.793
# 345      Kick Sauber 0 days 00:27:51.298000 2024-07-27 14:13:21.748
# 346      Kick Sauber 0 days 00:32:22.882000 2024-07-27 14:17:53.332
# 347      Kick Sauber 0 days 00:34:23.384000 2024-07-27 14:19:53.834
#
#      TrackStatus  Position  Deleted                  DeletedReason  \
# 0              1       NaN    False
# 1              1       NaN    False
# 2              1       NaN    False
# 3              1       NaN    False
# 4              1       NaN    False
# ..           ...       ...      ...                            ...
# 343            1       NaN    False
# 344            1       NaN    False
# 345            1       NaN    False
# 346            1       NaN     True  TRACK LIMITS AT TURN 4 LAP 9
# 347            1       NaN    False
#
#      FastF1Generated IsAccurate
# 0              False      False
# 1              False       True
# 2              False      False
# 3              False       True
# 4              False       True
# ..               ...        ...
# 343            False       True
# 344            False      False
# 345            False      False
# 346            False       True
# 347            False      False
#
# [348 rows x 31 columns]

# %%
ver = quali.get_driver('VER')
ver
# Out:
# DriverNumber                                                          1
# BroadcastName                                              M VERSTAPPEN
# Abbreviation                                                        VER
# DriverId                                                 max_verstappen
# TeamName                                                Red Bull Racing
# TeamColor                                                        3671C6
# TeamId                                                         red_bull
# FirstName                                                           Max
# LastName                                                     Verstappen
# FullName                                                 Max Verstappen
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                
# 13 0 days 00:00:30.977000    316.0    182.0    195.0    305.0
# 14 0 days 00:00:40.693000    262.0    168.0      NaN    250.0
# 15 0 days 00:00:38.952000    288.0    164.0    222.0    253.0
# 16 0 days 00:00:30.324000    317.0    184.0    214.0    307.0
# 17 0 days 00:00:37.897000    271.0    173.0      NaN    280.0
# 18 0 days 00:00:33.098000    263.0    174.0    223.0    265.0
# 19 0 days 00:00:30.321000    317.0    181.0    215.0    306.0
# 20 0 days 00:00:49.633000    218.0    151.0      NaN    233.0

# %%
fastest_max = max_laps.pick_fastest()
tele_max = fastest_max.get_telemetry().add_distance()
tele_max.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      231      5  11240
# 3      232      5  11061
# 4      235      6  10702
# 5      242      6  10803
# 6      244      6  10892
# ..     ...    ...    ...
# 841    215      5  11256
# 842    218      5  11361
# 843    222      5  11466
# 844    226      5  11572
# 845    226      5  11632
#
# [844 rows x 3 columns]

# %%
lec = quali.get_driver('LEC')
lec
# Out:
# DriverNumber                                                         16
# BroadcastName                                                 C LECLERC
# Abbreviation                                                        LEC
# DriverId                                                        leclerc
# TeamName                                                        Ferrari
# TeamColor                                                        E80020
# TeamId                                                          ferrari
# FirstName                                                       Charles
# LastName                                                        Leclerc
# FullName                                                Charles Leclerc
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         MON
# Position                                                            2.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:55.349000
# Q2                                               0 days 00:01:54.193000
# Q3                                               0 days 00:01:53.754000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 16, dtype: object

# %%
lec_laps = quali.laps.pick_driver("LEC")
lec_lap_time = lec_laps["LapTime"]
lec_sec1 = lec_laps["Sector1Time"]
lec_sec2 = lec_laps["Sector2Time"]
lec_sec3 = lec_laps["Sector3Time"]
lec_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
#                   LapTime            Sector1Time            Sector2Time  \
# 21                    NaT                    NaT 0 days 00:01:03.775000
# 22 0 days 00:01:57.698000 0 days 00:00:32.982000 0 days 00:00:53.962000
# 23 0 days 00:02:25.399000 0 days 00:00:34.742000 0 days 00:01:09.454000
# 24 0 days 00:01:56.144000 0 days 00:00:32.581000 0 days 00:00:52.936000
# 25                    NaT 0 days 00:00:41.503000 0 days 00:01:09.093000
# 26                    NaT 0 days 00:01:02.922000 0 days 00:00:58.627000
# 27 0 days 00:01:55.349000 0 days 00:00:32.280000 0 days 00:00:52.340000
# 28 0 days 00:02:17.344000 0 days 00:00:35.004000 0 days 00:01:02.011000
# 29                    NaT                    NaT 0 days 00:01:03.335000
# 30 0 days 00:01:55.388000 0 days 00:00:32.385000 0 days 00:00:52.158000
# 31 0 days 00:02:11.416000 0 days 00:00:34.766000 0 days 00:00:58.227000
# 32                    NaT 0 days 00:00:52.987000 0 days 00:00:59.571000
# 33 0 days 00:01:54.587000 0 days 00:00:32.219000 0 days 00:00:51.771000
# 34                    NaT 0 days 00:00:37.463000 0 days 00:01:17.460000
# 35 0 days 00:01:54.193000 0 days 00:00:32.351000 0 days 00:00:51.176000
# 36                    NaT 0 days 00:00:39.183000 0 days 00:01:12.012000
# 37                    NaT                    NaT 0 days 00:00:57.759000
# 38 0 days 00:01:54.518000 0 days 00:00:32.356000 0 days 00:00:51.519000
# 39 0 days 00:02:08.550000 0 days 00:00:35.151000 0 days 00:00:55.402000
# 40                    NaT                    NaT 0 days 00:00:55.800000
# 41 0 days 00:01:53.754000 0 days 00:00:32.040000 0 days 00:00:51.286000
# 42                    NaT 0 days 00:00:39.278000 0 days 00:01:03.846000
#
#               Sector3Time  SpeedI1  SpeedI2  SpeedFL  SpeedST
# 21 0 days 00:00:34.774000    272.0    168.0    216.0    252.0
# 22 0 days 00:00:30.754000    312.0    181.0    214.0    288.0
# 23 0 days 00:00:41.203000    247.0    156.0    214.0    257.0
# 24 0 days 00:00:30.627000    313.0    184.0    214.0    304.0
# 25 0 days 00:00:41.373000    217.0    153.0      NaN    214.0
# 26 0 days 00:00:32.984000    274.0    181.0    220.0    258.0
# 27 0 days 00:00:30.729000    314.0    189.0    213.0    302.0
# 28 0 days 00:00:40.329000    301.0    160.0      NaN    286.0
# 29 0 days 00:00:42.980000    274.0    173.0    217.0    244.0
# 30 0 days 00:00:30.845000    316.0    181.0    210.0    302.0
# 31 0 days 00:00:38.423000    290.0    174.0      NaN    281.0
# 32 0 days 00:00:41.779000    276.0    171.0    216.0    256.0
# 33 0 days 00:00:30.597000    317.0    187.0    212.0    304.0
# 34 0 days 00:00:49.953000    214.0    138.0    215.0    237.0
# 35 0 days 00:00:30.666000    315.0    189.0    209.0    306.0
# 36 0 days 00:00:40.491000    200.0    156.0      NaN    230.0
# 37 0 days 00:00:48.366000    289.0    170.0    219.0    253.0
# 38 0 days 00:00:30.643000    316.0    179.0    212.0    306.0
# 39 0 days 00:00:37.997000    288.0    171.0      NaN    277.0
# 40 0 days 00:00:38.322000    292.0    179.0    220.0    268.0
# 41 0 days 00:00:30.428000    317.0    185.0    212.0    307.0
# 42 0 days 00:00:58.897000    233.0    157.0      NaN    244.0

# %%
fastest_lec = lec_laps.pick_fastest()
tele_lec = fastest_lec.get_telemetry().add_distance()
tele_lec.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      236      5  10779
# 3      239      6  10898
# 4      240      6  11028
# 5      241      6  11159
# 6      250      6  11351
# ..     ...    ...    ...
# 860    213      5  11388
# 861    218      5  11480
# 862    220      5  11464
# 863    222      5  11449
# 864    223      5  11264
#
# [863 rows x 3 columns]

# %%
ham = quali.get_driver('HAM')
ham
# Out:
# DriverNumber                                                         44
# BroadcastName                                                L HAMILTON
# Abbreviation                                                        HAM
# DriverId                                                       hamilton
# TeamName                                                       Mercedes
# TeamColor                                                        27F4D2
# TeamId                                                         mercedes
# FirstName                                                         Lewis
# LastName                                                       Hamilton
# FullName                                                 Lewis Hamilton
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         GBR
# Position                                                            4.0
# ClassifiedPosition
# GridPosition                                                        NaN
# Q1                                               0 days 00:01:55.692000
# Q2                                               0 days 00:01:54.037000
# Q3                                               0 days 00:01:53.835000
# Time                                                                NaT
# Status
# Points                                                              NaN
# Name: 44, dtype: object

# %%
ham_laps = quali.laps.pick_driver("HAM")
ham_lap_time = ham_laps["LapTime"]
ham_sec1 = ham_laps["Sector1Time"]
ham_sec2 = ham_laps["Sector2Time"]
ham_sec3 = ham_laps["Sector3Time"]
ham_laps.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#      Speed  nGear    RPM
# 2      231      6  10929
# 3      233      6  11016
# 4      236      6  11162
# 5      240      6  11309
# 6      242      6  11367
# ..     ...    ...    ...
# 852    208      5  11347
# 853    215      5  11474
# 854    218      5  11694
# 855    221      5  11915
# 856    226      5  11396
#
# [855 rows x 3 columns]

# %%
plt.style.use("cyberpunk")
fig, ax = plt.subplots(2, 1, figsize=(7, 7), height_ratios=[2, 1])

ax[0].plot(tele_max.Distance, tele_max.Speed, label="Verstappen")
ax[0].plot(tele_lec.Distance,tele_lec.Speed,label = "Leclerc")
ax[0].plot(tele_ham.Distance,tele_ham.Speed,label = "Hamilton")
ax[0].set_title("Speed vs Distance", fontsize=16)
ax[0].set_xlabel("Distance", fontsize=12)
ax[0].set_ylabel("Speed", fontsize=12)
ax[0].legend(fontsize=10)
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

ax[1].plot(tele_max.Distance, tele_max.Throttle, label="Verstappen")
ax[1].plot(tele_lec.Distance,tele_lec.Throttle,label = "Leclerc")
ax[1].plot(tele_ham.Distance,tele_ham.Throttle,label = "Hamilton")
ax[1].set_title("Throttle vs Distance", fontsize=14)
ax[1].set_xlabel("Distance", fontsize=10)
ax[1].set_ylabel("Throttle", fontsize=10)
ax[1].legend(fontsize=8)
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()

# %%
def convert_to_normal(time):
    if pd.isna(time):
        return time 
    
    time_str = str(time)  
    parts = time_str.split()
    
    days = int(parts[0])
    minutes, seconds_with_microseconds = parts[2].split(':')[1:]
    seconds, microseconds = seconds_with_microseconds.split('.')
    
    minutes = int(minutes)
    seconds = int(seconds)
    microseconds = int(microseconds)
    
    total_microseconds = days * 86400000000 + minutes * 60000000 + seconds * 1000000 + microseconds
    
    minutes, remaining_microseconds = divmod(total_microseconds, 60000000)
    seconds, microseconds = divmod(remaining_microseconds, 1000000)
    
    normal_time = f"{minutes:02d}:{seconds:02d}.{microseconds:06d}"
    return normal_time

# %%
driver1_sectors = pd.DataFrame(
    {
        "Driver": ["Vertappen"] * len(max_sec1),
        "Sector1Time": max_sec1,
        "Sector2Time": max_sec2,
        "Sector3Time": max_sec3,
        "Lap Time": max_lap_time,
    }
)


driver3_sectors = pd.DataFrame(
    {
        "Driver": ["Leclerc"] * len(lec_sec1),
        "Sector1Time": lec_sec1,
        "Sector2Time": lec_sec2,
        "Sector3Time": lec_sec3,
        "Lap Time": lec_lap_time,
    }
)

driver4_sectors = pd.DataFrame(
    {
        "Driver": ["Hamilton"] * len(ham_sec1),
        "Sector1Time": ham_sec1,
        "Sector2Time": ham_sec2,
        "Sector3Time": ham_sec3,
        "Lap Time": ham_lap_time,
    }
)


all_drivers_sectors = pd.concat(
    [driver1_sectors, driver3_sectors, driver4_sectors],
    ignore_index=True,
)
all_drivers_sectors["Sector1Time"] = all_drivers_sectors["Sector1Time"].apply(
    convert_to_normal
)
all_drivers_sectors["Sector2Time"] = all_drivers_sectors["Sector2Time"].apply(
    convert_to_normal
)
all_drivers_sectors["Sector3Time"] = all_drivers_sectors["Sector3Time"].apply(
    convert_to_normal
)
all_drivers_sectors["Lap Time"] = all_drivers_sectors["Lap Time"].apply(
    convert_to_normal
)
all_drivers_sectors.sort_values(
    by=["Sector1Time", "Sector2Time", "Sector3Time"], ascending=True
)
# Out:
#        Driver   Sector1Time   Sector2Time   Sector3Time      Lap Time
# 19  Vertappen  00:31.941000  00:50.939000  00:30.321000  01:53.201000
# 16  Vertappen  00:31.998000  00:50.837000  00:30.324000  01:53.159000
# 11  Vertappen  00:32.029000  00:51.280000  00:30.528000  01:53.837000
# 41    Leclerc  00:32.040000  00:51.286000  00:30.428000  01:53.754000
# 64   Hamilton  00:32.060000  00:52.014000           NaT           NaT
# ..        ...           ...           ...           ...           ...
# 18  Vertappen           NaT  00:58.177000  00:33.098000           NaT
# 8   Vertappen           NaT  01:02.040000  00:43.629000           NaT
# 29    Leclerc           NaT  01:03.335000  00:42.980000           NaT
# 21    Leclerc           NaT  01:03.775000  00:34.774000           NaT
# 43   Hamilton           NaT  01:06.945000  00:35.242000           NaT
#
# [65 rows x 5 columns]

# %% [markdown]
# **Race**

# %%
race = f1.get_session(2024,"Belgium","R")
race.load()
# Out:
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.3.9]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['44', '81', '16', '1', '4', '55', '11', '14', '31', '3', '18', '23', '10', '20', '77', '22', '2', '27', '24', '63']

# %%
race.results.loc[:,["Abbreviation","TeamName","GridPosition","Position","Time","Status"]]
# Out:
# 836       40.0    2.0        NaT       NaT 0 days 00:00:30.989000
# 837       41.0    2.0        NaT       NaT 0 days 00:00:30.926000
# 838       42.0    2.0        NaT       NaT 0 days 00:00:31.014000
# 839       43.0    2.0        NaT       NaT 0 days 00:00:30.990000
# 840       44.0    2.0        NaT       NaT 0 days 00:00:30.990000
#
#                Sector2Time  ... FreshTyre      Team           LapStartTime  \
# 0   0 days 00:00:49.406000  ...      True  Mercedes 0 days 00:55:14.764000
# 1   0 days 00:00:49.211000  ...      True  Mercedes 0 days 00:57:07.801000
# 2   0 days 00:00:48.486000  ...      True  Mercedes 0 days 00:58:57.650000
# 3   0 days 00:00:48.605000  ...      True  Mercedes 0 days 01:00:46.759000
# 4   0 days 00:00:48.320000  ...      True  Mercedes 0 days 01:02:36.567000
# ..                     ...  ...       ...       ...                    ...
# 836 0 days 00:00:47.555000  ...      True  Mercedes 0 days 02:06:14.877000
# 837 0 days 00:00:47.796000  ...      True  Mercedes 0 days 02:08:02.508000
# 838 0 days 00:00:47.525000  ...      True  Mercedes 0 days 02:09:50.262000
# 839 0 days 00:00:47.479000  ...      True  Mercedes 0 days 02:11:37.727000
# 840 0 days 00:00:47.172000  ...      True  Mercedes 0 days 02:13:25.028000
#
#                LapStartDate  TrackStatus  Position  Deleted  DeletedReason  \
# 0   2024-07-28 13:03:52.742            1       2.0    False
# 1   2024-07-28 13:05:45.779            1       2.0    False
# 2   2024-07-28 13:07:35.628            1       1.0    False
# 3   2024-07-28 13:09:24.737            1       1.0    False
# 4   2024-07-28 13:11:14.545            1       1.0    False
# ..                      ...          ...       ...      ...            ...
# 836 2024-07-28 14:14:52.855            1       1.0    False
# 837 2024-07-28 14:16:40.486            1       1.0    False
# 838 2024-07-28 14:18:28.240            1       1.0    False
# 839 2024-07-28 14:20:15.705            1       1.0    False
# 840 2024-07-28 14:22:03.006            1       1.0    False
#
#      FastF1Generated IsAccurate
# 0              False      False
# 1              False       True
# 2              False       True
# 3              False       True
# 4              False       True
# ..               ...        ...
# 836            False       True
# 837            False       True
# 838            False       True
# 839            False       True
# 840            False       True
#
# [841 rows x 31 columns]

# %%
ham_race = race.laps.pick_driver("HAM")
fastest_lap_ham_race = ham_race.pick_fastest().LapTime
ham_race_lap_time = ham_race["LapTime"]
ham_race_sec1 = ham_race["Sector1Time"]
ham_race_sec2 = ham_race["Sector2Time"]
ham_race_sec3 = ham_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_ham_race),"which was in Lap number",ham_race.pick_fastest().LapNumber)
ham_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:46.653000 which was in Lap number 33.0
#                   LapTime            Sector1Time            Sector2Time  \
# 0  0 days 00:01:52.700000                    NaT 0 days 00:00:49.406000
# 1  0 days 00:01:49.849000 0 days 00:00:31.284000 0 days 00:00:49.211000
# 2  0 days 00:01:49.109000 0 days 00:00:31.215000 0 days 00:00:48.486000
# 3  0 days 00:01:49.808000 0 days 00:00:31.754000 0 days 00:00:48.605000
# 4  0 days 00:01:49.376000 0 days 00:00:31.592000 0 days 00:00:48.320000
# 5  0 days 00:01:49.400000 0 days 00:00:31.618000 0 days 00:00:48.355000
# 65 0 days 00:00:29.064000      NaN    201.0    219.0    315.0
# 66 0 days 00:00:29.329000    317.0    204.0    218.0      NaN
# 67 0 days 00:00:28.900000    315.0    203.0    220.0    314.0
# 68 0 days 00:00:28.819000    317.0    205.0    221.0    315.0
# 69 0 days 00:00:28.880000    318.0    206.0    220.0    314.0
# 70 0 days 00:00:28.772000    316.0    207.0    220.0      NaN
# 71 0 days 00:00:29.055000    314.0    201.0    220.0      NaN
# 72 0 days 00:00:28.944000    316.0    204.0    219.0      NaN
# 73 0 days 00:00:33.170000    317.0    208.0      NaN      NaN
# 74 0 days 00:00:28.419000    319.0    212.0    224.0    312.0
# 75 0 days 00:00:28.618000    318.0    209.0    223.0    317.0
# 76 0 days 00:00:28.877000    320.0    208.0    220.0    318.0
# 77 0 days 00:00:28.731000    325.0    210.0    223.0    320.0
# 78 0 days 00:00:29.342000    347.0    206.0    224.0      NaN
# 79 0 days 00:00:28.969000    348.0    208.0    222.0    318.0
# 80        0 days 00:00:29    317.0    207.0    221.0    316.0
# 81 0 days 00:00:28.797000    319.0    209.0    222.0      NaN
# 82 0 days 00:00:28.773000    316.0    205.0    222.0      NaN
# 83 0 days 00:00:28.685000    317.0    210.0    223.0    318.0
# 84 0 days 00:00:28.894000    319.0    209.0    222.0    317.0
# 85 0 days 00:00:28.662000      NaN    208.0    222.0    320.0
# 86 0 days 00:00:28.739000    326.0    207.0    222.0    319.0
# 87 0 days 00:00:28.706000    338.0    208.0    223.0      NaN

# %%
fastest_lap_race_pia = pia_race.pick_fastest()
tele_race_pia= fastest_lap_race_pia.get_telemetry().add_distance()
speed_race_pia = tele_race_pia.Speed
tele_race_pia.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      238      6  10883
# 3      239      6  10939
# 4      242      6  11052
# 5      245      6  11188
# 6      248      6  11325
# ..     ...    ...    ...
# 808    225      5  11685
# 809    229      5  11191
# 810    233      6  10697
# 811    234      6  10808
# 812    235      6  10864
#
# [811 rows x 3 columns]

# %%
lec_race = race.laps.pick_driver("LEC")
fastest_lap_lec_race = lec_race.pick_fastest().LapTime
lec_race_lap_time = lec_race["LapTime"]
lec_race_sec1 = lec_race["Sector1Time"]
lec_race_sec2 = lec_race["Sector2Time"]
lec_race_sec3 = lec_race["Sector3Time"]
print("Fastest Lap:",convert_to_normal(fastest_lap_lec_race),"which was in Lap number",lec_race.pick_fastest().LapNumber)
lec_race.loc[:,["LapTime","Sector1Time","Sector2Time","Sector3Time","SpeedI1","SpeedI2","SpeedFL","SpeedST"]]
# Out:
# Fastest Lap: 01:47.013000 which was in Lap number 33.0
#                    LapTime            Sector1Time            Sector2Time  \
# 88  0 days 00:01:51.912000                    NaT 0 days 00:00:48.663000
# 89  0 days 00:01:50.240000 0 days 00:00:31.831000 0 days 00:00:48.675000
# 90  0 days 00:01:50.519000 0 days 00:00:31.833000 0 days 00:00:49.132000
# 91  0 days 00:01:49.796000 0 days 00:00:31.592000 0 days 00:00:48.778000
# 92  0 days 00:01:49.494000 0 days 00:00:31.394000 0 days 00:00:48.729000
# 129 0 days 00:00:28.897000    324.0    207.0    219.0    316.0
# 130 0 days 00:00:28.851000    322.0    210.0    219.0    313.0
# 131 0 days 00:00:29.033000      NaN    209.0    220.0    314.0

# %%
fastest_lap_race_lec = lec_race.pick_fastest()
tele_race_lec= fastest_lap_race_lec.get_telemetry().add_distance()
speed_race_lec = tele_race_lec.Speed
tele_race_lec.loc[:,["Speed","nGear","RPM"]]
# Out:
#      Speed  nGear    RPM
# 2      230      5  10354
# 3      232      5  10254
# 4      236      6  10054
# 5      238      6  10911
# 6      238      6  10981
# ..     ...    ...    ...
# 804    215      5  11462
# 805    218      5  11614
# 806    220      5  11181
# 807    223      5  10749
# 808    227      5  10795
#
# [807 rows x 3 columns]

# %%
fig, ax = plt.subplots(2, 1, figsize=(7, 7), height_ratios=[2, 1])

ax[0].plot(tele_race_pia.Distance,tele_race_pia.Speed,label = "Piastri")
ax[0].plot(tele_race_lec.Distance, tele_race_lec.Speed, label="Leclerc")
ax[0].plot(tele_race_ham.Distance,tele_race_ham.Speed,label = "Hamiltion")
ax[0].set_title("Speed vs Distance", fontsize=16)
ax[0].set_xlabel("Distance", fontsize=12)
ax[0].set_ylabel("Speed", fontsize=12)
ax[0].legend(fontsize=10)
ax[0].grid(True)
ax[0].tick_params(axis='both', which='major', labelsize=10)

ax[1].plot(tele_race_pia.Distance,tele_race_pia.Throttle,label = "Piastri")
ax[1].plot(tele_race_lec.Distance, tele_race_lec.Throttle, label="Leclerc")
ax[1].plot(tele_race_ham.Distance,tele_race_ham.Throttle,label = "Hamiltion")
ax[1].set_title("Throttle vs Distance", fontsize=14)
ax[1].set_xlabel("Distance", fontsize=10)
ax[1].set_ylabel("Throttle", fontsize=10)
ax[1].legend(fontsize=8)
ax[1].grid(True)
ax[1].tick_params(axis='both', which='major', labelsize=8)

plt.tight_layout()
plt.show()

# %%
driver1_sectors = pd.DataFrame({
    'Driver': ['Leclerc'] * len(lec_race_sec1),
    'Sector1Time': lec_race_sec1,
    'Sector2Time': lec_race_sec2,
    'Sector3Time': lec_race_sec3,
    'Lap Time' : lec_race_lap_time
})

driver2_sectors = pd.DataFrame({
    'Driver': ['Hamilton'] * len(ham_race_sec1),
    'Sector1Time': ham_race_sec1,
    'Sector2Time': ham_race_sec2,
    'Sector3Time': ham_race_sec3,
    'Lap Time' : ham_race_lap_time
})

driver3_sectors = pd.DataFrame({
    'Driver': ['Piastri'] * len(pia_race_sec1),
    'Sector1Time': pia_race_sec1,
    'Sector2Time': pia_race_sec2,
    'Sector3Time': pia_race_sec3,
    'Lap Time' : pia_race_lap_time
})



all_drivers_sectors = pd.concat([driver1_sectors, driver2_sectors, driver3_sectors], ignore_index=True)
# all_drivers_sectors['Sector1Time'] = all_drivers_sectors['Sector1Time'].apply(convert_to_normal)
all_drivers_sectors['Sector2Time'] = all_drivers_sectors['Sector2Time'].apply(convert_to_normal)
# all_drivers_sectors['Sector3Time'] = all_drivers_sectors['Sector3Time'].apply(convert_to_normal)
all_drivers_sectors['Lap Time'] = all_drivers_sectors['Lap Time'].apply(convert_to_normal)
all_drivers_sectors.sort_values(by=["Sector1Time","Sector2Time","Sector3Time"],ascending=True)
# Out:
#        Driver            Sector1Time   Sector2Time            Sector3Time  \
# 122   Piastri 0 days 00:00:30.406000  00:48.564000 0 days 00:00:29.342000
# 123   Piastri 0 days 00:00:30.425000  00:47.785000 0 days 00:00:28.969000
# 131   Piastri 0 days 00:00:30.498000  00:47.424000 0 days 00:00:28.706000
# 100   Piastri 0 days 00:00:30.566000  00:48.099000 0 days 00:00:28.900000
# 121   Piastri 0 days 00:00:30.627000  00:47.170000 0 days 00:00:28.731000
# ..        ...                    ...           ...                    ...
# 25    Leclerc 0 days 00:00:46.201000  00:46.740000 0 days 00:00:29.031000
# 118   Piastri 0 days 00:00:46.496000  00:46.509000 0 days 00:00:28.419000
# 0     Leclerc                    NaT  00:48.663000 0 days 00:00:29.571000
# 44   Hamilton                    NaT  00:49.406000 0 days 00:00:29.478000
# 88    Piastri                    NaT  00:50.480000 0 days 00:00:29.643000
#
#          Lap Time
# 122  01:48.312000
# 123  01:47.179000
# 131  01:46.628000
# 100  01:47.565000
# 121  01:46.528000
# ..            ...
# 25   02:01.972000
# 118  02:01.424000
# 0    01:51.912000
# 44   01:52.700000
# 88   01:54.248000
#
# [132 rows x 5 columns]

# %%
drivers = race.laps.Driver.unique()
drivers_ab = drivers.tolist()
nlaps = race.laps.LapNumber.unique().max()

for driver in drivers_ab:
    positions = laps[laps['Driver'] == driver]['Position'].values  
    plt.plot(range(1, len(positions) + 1), positions, label=driver)

plt.title("Driver Positions Over Laps")
plt.grid(True, linestyle=':', alpha=0.5)
plt.xlim(1, float(nlaps))
plt.xlabel("Lap Number")
plt.ylim(0, 21)
plt.ylabel("Position")
plt.gca().invert_yaxis()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
def getDriverPosition(abbreviation: str):
    res = race.results
    c = res["Abbreviation"] == abbreviation
    pos = res.loc[c, ["Position"]]
    posi = pos.iloc[-1]
    return int(posi.iloc[0])


def getCompound(abbreviation: str):
    driver_race = race.laps.pick_driver(abbreviation)
    lastLap = driver_race.LapNumber.count()
    if driver_race["TyreLife"].iloc[0] == 1.0:
        condition = driver_race["TyreLife"] == 1
        driver_comp = driver_race.loc[condition, ["Compound", "LapNumber"]]
        compound = driver_comp.Compound.tolist()
        return compound, driver_comp, lastLap
    else:
        compound = []
        result = []
        for i in range(0, len(driver_race["TyreLife"])):
            if driver_race["TyreLife"].iloc[i] < driver_race["TyreLife"].iloc[i - 1]:
                result.append(
                    {
                        "Compound": driver_race["Compound"].iloc[i],
                        "LapNumber": driver_race["LapNumber"].iloc[i],
                    }
                )
                compound.append(driver_race["Compound"].iloc[i])

        driver_comp = pd.DataFrame(result)
        return compound, driver_comp, lastLap


fig, ax = plt.subplots(figsize=(10, 6))

color_mapping = {
    "MEDIUM": "yellow",
    "SOFT": "red",
    "HARD": "white",
    "INTERMEDIATE": "green",
    "WET": "blue",
}
drivers = race.laps.Driver.unique()
drivers_ab = drivers.tolist()
used_labels = set()
for driver in drivers_ab:
    compound, driver_comp, lastLap = getCompound(driver)

    list1 = driver_comp.LapNumber.tolist()
    list1.append(lastLap)
    int_list = [int(x) for x in list1]
    x_points = int_list
    n = len(int_list)
    posi = getDriverPosition(driver)
    y_points = [posi] * n

    for i in range(len(driver_comp.LapNumber)):
        x_segment = [x_points[i], x_points[i + 1]]
        y_segment = [y_points[i], y_points[i + 1]]
        tire_color = color_mapping.get(compound[i], "unknown")
        label = compound[i] if compound[i] not in used_labels else None
        
        ax.plot(x_segment, y_segment, color=tire_color, linewidth=2, label=label)
        used_labels.add(compound[i])

        ax.text(
            x_points[i + 1],
            y_points[i + 1],
            str(x_points[i + 1]),
            fontsize=12,
            ha="center",
            va="center",
            bbox=dict(facecolor="black", edgecolor="white", pad=1),
        )
        ax.annotate(f'{i}',
                xy=(0, 1),
                xytext=(-10, 0),
                textcoords='offset points',
                va='center',
                ha='right',
                color="white",
                fontweight='bold')

ax.set_xlim(1, 53)
ax.invert_yaxis()
ax.set_ylim(21, 0)
ax.set_title("Pit Stop Strategy Position wise")
ax.set_xlabel("Laps")
ax.set_ylabel("Position")
ax.axvline(x=0, color='black', linewidth=2)
ax.grid(True, linestyle="-", alpha=0.7)
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.show()

# %%
res = race.results
drivers = res['Abbreviation'].tolist()
fastest_speed = pd.DataFrame(columns=['Driver', 'Speed'])
for i in drivers:
    tele = race.laps.pick_driver(i)
    speed = tele.SpeedST.max()
    df = pd.DataFrame({'Driver': [i], 'Speed': [speed]})
    fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
fastest_speed.sort_values(by="Speed",ascending=True)
# Out:
# /tmp/ipykernel_93622/2770152713.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fastest_speed = pd.concat([fastest_speed, df], ignore_index=True)
#    Driver  Speed
# 18    ZHO  314.0
# 10    STR  315.0
# 6     PER  315.0
# 9     RIC  316.0
# 2     LEC  316.0
# 15    TSU  317.0
# 7     ALO  317.0
# 0     HAM  317.0
# 19    RUS  317.0
# 13    MAG  318.0
# 3     VER  319.0
# 14    BOT  319.0
# 5     SAI  319.0
# 11    ALB  320.0
# 1     PIA  320.0
# 16    SAR  320.0
# 17    HUL  321.0
# 4     NOR  322.0
# 12    GAS  324.0
# 8     OCO  325.0

# %%
fig,ax = plt.subplots(figsize=(18, 6))


bars = ax.bar(fastest_speed['Driver'], fastest_speed['Speed'])

ax.set_xlabel('Drivers')

ax.set_ylabel('Speed')

ax.set_title('Maximum Speeds of Drivers')

plt.xticks(rotation=45, ha='right')

y_min = 275
y_max = np.ceil(fastest_speed['Speed'].max() / 5) * 5 + 5
y_ticks = np.arange(y_min, y_max, 5)
ax.set_ylim(y_min, y_max)
ax.set_yticks(y_ticks)

for bar in bars:
    height = bar.get_height()
    ax.annotate('{:.2f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

# Display the plot
plt.show()
